# %% [markdown]
# # Feature Selection Example (not done)
# Coming soon.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from dateutil.relativedelta import relativedelta
from scalecast.Forecaster import Forecaster
from sklearn.linear_model import Lasso

sns.set(rc={'figure.figsize':(12,8)})
pd.options.display.max_rows = None
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

model_params = dict(
    test_only = True,
    dynamic_testing = True,
)

dynamic_tuning = False
patience = 5

# %%
def prepare_fcst(
    f,
    test_length=.1,
    fcst_length=1
):
    f.generate_future_dates(fcst_length)
    f.set_test_length(test_length)
    f.set_validation_length(120)
    f.add_seasonal_regressors('month','quarter',raw=False,sincos=True)
    f.set_validation_metric('mae')
    for i in np.arange(12,289,12): # 12-month cycles from 12 to 288 months
        f.add_cycle(i)
    f.add_ar_terms(120) # AR 1-120
    f.add_AR_terms((20,12)) # seasonal AR up to 20 years, spaced one year apart
    f.add_time_trend()
    f.add_seasonal_regressors('year')
    return f

def sort_pfi_df(df):
    df['weight'] = np.abs(df['weight'])
    return df.sort_values(['weight','std'],ascending=False)

def reduce_vars(
    f,
    features,
    call_me,
    monitor="ValidationMetricValue", # don't use R2 without a proper modification
    patience=5,
    rebuild_fi_df=True,
):
    """ reduces variables one-by-one using evaluated feature importance, reducing the worst-performing variables first
    
    Args:
        f (Forecaster): the Forecaster object to evaluate models with.
        features (list-like): the list of variables to try sorted from most-to-least important.
        call_me (str): the name of the resulting reduced model stored in f.
        patience (int): the number of iterations to wait before giving up.
        monitor (str): one of Forecaster._determine_best_by_.
            the metric to monitor to see if improvements are being made.
            do not use R2 unless you modify this function appropriately.
        rebuild_fi_df (bool): whether to recreate the permutated feature scores after each model eval.
            if not using pfi, set this to False.
    
    Returns:
        None
    """
    init_error = f.history[f.estimator][monitor]
    hp = f.history[f.estimator]['HyperParams']
    best_error = init_error
    print(f'beginning {monitor}: {init_error}')
    
    grid = grids[f.estimator]
    dropped = []
    errors = [init_error]
    
    i = 0
    while len(dropped) < (len(f.get_regressor_names()) - 1):
        print('dropping {}'.format(features[-1]))
        dropped.append(features[-1])
        features = features[:-1]
        grid['Xvars'] = [features]
        f.ingest_grid(grid)
        f.tune(dynamic_tuning=dynamic_tuning)
        f.auto_forecast(
            **model_params,
            call_me = call_me,
        )
        new_error = f.history[call_me][monitor]
        errors.append(new_error)
        
        if rebuild_fi_df:
            f.save_feature_importance()
            fi_df = f.export_feature_importance(call_me)
            fi_df = sort_pfi_df(fi_df)
            features = fi_df.index.to_list()
        
        if best_error <= new_error: # no reduction
            i+=1
        else: # reduction
            best_error = new_error 
            print(f'error reduced to {best_error}')
            i = 0
        
        if i == patience:
            break
   
    if len(dropped) == patience:
        f.pop(call_me)
        print('feature reduction yielded no results')
    else:
        final_Xvars = f.history[call_me]['Xvars'][:-patience]
        final_hp = f.history[call_me]['HyperParams']
        f.manual_forecast(
            **model_params,
            **final_hp,
            Xvars = final_Xvars,
            call_me = call_me,
        )
        print(f'last {patience} vars added back')
        print(f'final model trained with {len(final_Xvars)} vars')
        print(f'final {monitor}: {f.history[call_me][monitor]}')
    return dropped, errors

def plot_errors(dropped,errors):
    _, ax = plt.subplots()
    sns.lineplot(
        x=np.arange(0,len(dropped)+1,1),
        y=errors,
        label='actual error',
    )
    sns.regplot(
        x=np.arange(0,len(dropped)+1,1),
        y=errors,
        ci=None,
        color=sns.color_palette()[1],
        order=2,
    )
    plt.xlabel('dropped Xvars')
    plt.ylabel('error')
    return ax
    
def export_results(f):
    results = f.export('model_summaries',determine_best_by='TestSetMAE')
    results['N_Xvars'] = results['Xvars'].apply(lambda x: len(x))
    return results[
        [
            'ModelNickname',
            'TestSetMAE',
            'InSampleMAE',
            'TestSetR2',
            'InSampleR2',
            'ValidationMetric',
            'ValidationMetricValue',
            'HyperParams',
            'N_Xvars'
        ]
    ]

# %%
grids = {
    'gbt':dict(
        n_estimators=[10000],
        max_depth=[2],
        max_features=['log2'],
    ),
    'lasso':dict(
        alpha=[0.025],
    ),
    'xgboost':dict(
        n_estimators=[2000,5000,10000],
        subsample=[0.8,0.9],
        max_depth=[1,2,3,6], 
    ),
}

# %%
df = pd.read_csv('Sunspots.csv',index_col=0,names=['Date','Target'],header=0)
f = Forecaster(y=df['Target'],current_dates=df['Date'])

# %%
prepare_fcst(f)
# Out:
# Forecaster(
#     DateStartActuals=1749-01-31T00:00:00.000000000
#     DateEndActuals=2021-01-31T00:00:00.000000000
#     Freq=M
#     N_actuals=3265
#     ForecastLength=1
#     Xvars=['monthsin', 'monthcos', 'quartersin', 'quartercos', 'cycle12sin', 'cycle12cos', 'cycle24sin', 'cycle24cos', 'cycle36sin', 'cycle36cos', 'cycle48sin', 'cycle48cos', 'cycle60sin', 'cycle60cos', 'cycle72sin', 'cycle72cos', 'cycle84sin', 'cycle84cos', 'cycle96sin', 'cycle96cos', 'cycle108sin', 'cycle108cos', 'cycle120sin', 'cycle120cos', 'cycle132sin', 'cycle132cos', 'cycle144sin', 'cycle144cos', 'cycle156sin', 'cycle156cos', 'cycle168sin', 'cycle168cos', 'cycle180sin', 'cycle180cos', 'cycle192sin', 'cycle192cos', 'cycle204sin', 'cycle204cos', 'cycle216sin', 'cycle216cos', 'cycle228sin', 'cycle228cos', 'cycle240sin', 'cycle240cos', 'cycle252sin', 'cycle252cos', 'cycle264sin', 'cycle264cos', 'cycle276sin', 'cycle276cos', 'cycle288sin', 'cycle288cos', 'AR1', 'AR2', 'AR3', 'AR4', 'AR5', 'AR6', 'AR7', 'AR8', 'AR9', 'AR10', 'AR11', 'AR12', 'AR13', 'AR14', 'AR15', 'AR16', 'AR17', 'AR18', 'AR19', 'AR20', 'AR21', 'AR22', 'AR23', 'AR24', 'AR25', 'AR26', 'AR27', 'AR28', 'AR29', 'AR30', 'AR31', 'AR32', 'AR33', 'AR34', 'AR35', 'AR36', 'AR37', 'AR38', 'AR39', 'AR40', 'AR41', 'AR42', 'AR43', 'AR44', 'AR45', 'AR46', 'AR47', 'AR48', 'AR49', 'AR50', 'AR51', 'AR52', 'AR53', 'AR54', 'AR55', 'AR56', 'AR57', 'AR58', 'AR59', 'AR60', 'AR61', 'AR62', 'AR63', 'AR64', 'AR65', 'AR66', 'AR67', 'AR68', 'AR69', 'AR70', 'AR71', 'AR72', 'AR73', 'AR74', 'AR75', 'AR76', 'AR77', 'AR78', 'AR79', 'AR80', 'AR81', 'AR82', 'AR83', 'AR84', 'AR85', 'AR86', 'AR87', 'AR88', 'AR89', 'AR90', 'AR91', 'AR92', 'AR93', 'AR94', 'AR95', 'AR96', 'AR97', 'AR98', 'AR99', 'AR100', 'AR101', 'AR102', 'AR103', 'AR104', 'AR105', 'AR106', 'AR107', 'AR108', 'AR109', 'AR110', 'AR111', 'AR112', 'AR113', 'AR114', 'AR115', 'AR116', 'AR117', 'AR118', 'AR119', 'AR120', 'AR132', 'AR144', 'AR156', 'AR168', 'AR180', 'AR192', 'AR204', 'AR216', 'AR228', 'AR240', 't', 'year']
#     Differenced=0
#     TestLength=326
#     ValidationLength=120
#     ValidationMetric=mae
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
# )

# %%
print('starting out with {} variables'.format(len(f.get_regressor_names())))
# Out:
# starting out with 184 variables

# %% [markdown]
# ## Reducing with Lasso

# %%
f.add_sklearn_estimator(Lasso,'lasso')
f.set_estimator('lasso')
f.ingest_grid(grids['lasso'])
f.tune(dynamic_tuning=dynamic_tuning)
f.auto_forecast(**model_params)
f.save_feature_importance()

# %%
coef_fi_lasso = pd.DataFrame(
    {x: [np.abs(co)] for x, co in zip(f.history['lasso']['Xvars'],f.regr.coef_)},
    index = ['feature'],
).T.sort_values('feature',ascending=False)
coef_fi_lasso.tail()
# Out:
#       feature
# AR50   0.0000
# AR49   0.0000
# AR48   0.0000
# AR47   0.0000
# year   0.0000

# %%
print('lasso model reduced {} variable coefficients to 0, leaving {} variables with effects in the model'.format(
    coef_fi_lasso.loc[coef_fi_lasso['feature'] == 0].shape[0],
    coef_fi_lasso.loc[coef_fi_lasso['feature'] != 0].shape[0],
))
# Out:
# lasso model reduced 78 variable coefficients to 0, leaving 106 variables with effects in the model

# %%
pfi_lasso = f.export_feature_importance('lasso')
pfi_lasso = sort_pfi_df(pfi_lasso)
pfi_lasso.tail()
# Out:
#          weight    std
# feature
# AR74     0.0000 0.0000
# AR75     0.0000 0.0000
# AR77     0.0000 0.0000
# AR144    0.0000 0.0000
# AR98     0.0000 0.0000

# %%
dropped, errors = reduce_vars(
    f,
    coef_fi_lasso.index.to_list(),
    'lasso_coef_reduced',
    patience=patience,
    rebuild_fi_df=False,
)

plot_errors(dropped,errors)
plt.show()
# Out:
# beginning ValidationMetricValue: 20.87019235103221
# dropping year
# dropping AR47
# error reduced to 20.867806070924164
# dropping AR48
# dropping AR49
# dropping AR50
# dropping AR51
# dropping AR54
# final model trained with 177 variables
# final ValidationMetricValue: 20.867808712759423

# %%
dropped, errors = reduce_vars(
    f,
    pfi_lasso.index.to_list(),
    'lasso_pfi_reduced',
    patience=patience,
)

plot_errors(dropped,errors)
plt.show()
# Out:
# beginning ValidationMetricValue: 20.87019235103221
# dropping AR98
# error reduced to 20.84243298615707
# dropping AR85
# dropping AR65
# dropping cycle240sin
# dropping AR115
# dropping AR66
# error reduced to 20.842316392499683
# dropping AR103
# dropping AR82
# dropping AR144
# dropping AR95
# dropping AR68
# final model trained with 173 variables
# final ValidationMetricValue: 20.84295423716011

# %%
export_results(f)
# Out:
#         ModelNickname  TestSetMAE  InSampleMAE  TestSetR2  InSampleR2  \
# 0               lasso     45.5011      17.3371     0.1459      0.8818
# 1  lasso_coef_reduced     45.5250      17.3361     0.1450      0.8818
# 2   lasso_pfi_reduced     45.5266      17.3365     0.1447      0.8818
#
#         HyperParams  N_Xvars
# 0  {'alpha': 0.025}      184
# 1  {'alpha': 0.025}      177
# 2  {'alpha': 0.025}      173

# %% [markdown]
# ## Reducing with GBT

# %%
f.set_estimator('gbt')
f.ingest_grid(grids['gbt'])
f.tune(dynamic_tuning=dynamic_tuning)
f.auto_forecast(**model_params)
f.save_feature_importance()

# %%
gini_fi_gbt = pd.DataFrame(
    {x: [fi] for x, fi in zip(f.history['gbt']['Xvars'],f.regr.feature_importances_)},
    index = ['feature'],
).T.sort_values('feature',ascending=False)
gini_fi_gbt.tail()
# Out:
#             feature
# cycle24sin   0.0001
# cycle12cos   0.0001
# monthcos     0.0000
# quartersin   0.0000
# quartercos   0.0000

# %%
pfi_gbt = f.export_feature_importance('gbt')
pfi_gbt = sort_pfi_df(pfi_gbt)
pfi_gbt.tail()
# Out:
#             weight    std
# feature
# cycle24sin  0.0002 0.0004
# cycle12sin  0.0001 0.0004
# quartersin  0.0001 0.0001
# quartercos  0.0001 0.0001
# AR74        0.0000 0.0078

# %%
dropped, errors = reduce_vars(
    f,
    gini_fi_gbt.index.to_list(),
    'gbt_gini_reduced',
    patience=patience,
    rebuild_fi_df=False,
)

plot_errors(dropped,errors)
plt.show()
# Out:
# beginning ValidationMetricValue: 36.97413156346629
# dropping quartercos
# error reduced to 29.59204286348588
# dropping quartersin
# error reduced to 25.751958921960643
# dropping monthcos
# error reduced to 21.869702976783206
# dropping cycle12cos
# dropping cycle24sin
# dropping cycle24cos
# dropping cycle12sin
# dropping cycle36cos
# final model trained with 176 variables
# final ValidationMetricValue: 25.629420586705084

# %%
dropped, errors = reduce_vars(
    f,
    pfi_gbt.index.to_list(),
    'gbt_pfi_reduced',
    patience=patience,
)

plot_errors(dropped,errors)
plt.show()
# Out:
# beginning ValidationMetricValue: 36.97413156346629
# dropping AR74
# error reduced to 25.767500475948648
# dropping quartercos
# error reduced to 23.770469030322726
# dropping cycle24sin
# dropping cycle72cos
# dropping monthcos
# dropping monthsin
# dropping cycle36sin
# error reduced to 22.45152945537649
# dropping cycle216cos
# dropping AR28
# dropping quartersin
# dropping cycle12sin
# dropping cycle192sin
# final model trained with 172 variables
# final ValidationMetricValue: 25.045417704201046

# %%
export_results(f)
# Out:
#         ModelNickname  TestSetMAE  InSampleMAE  TestSetR2  InSampleR2  \
# 0     gbt_pfi_reduced     25.0820       0.7737     0.6504      0.9998
# 1    gbt_gini_reduced     30.4877       0.7882     0.4983      0.9998
# 2               lasso     45.5011      17.3371     0.1459      0.8818
# 3  lasso_coef_reduced     45.5250      17.3361     0.1450      0.8818
# 4   lasso_pfi_reduced     45.5266      17.3365     0.1447      0.8818
# 5                 gbt     43.8911       0.7833    -0.3013      0.9998
#
#                                          HyperParams  N_Xvars
# 0  {'n_estimators': 10000, 'max_depth': 2, 'max_f...      172
# 1  {'n_estimators': 10000, 'max_depth': 2, 'max_f...      176
# 2                                   {'alpha': 0.025}      184
# 3                                   {'alpha': 0.025}      177
# 4                                   {'alpha': 0.025}      173
# 5  {'n_estimators': 10000, 'max_depth': 2, 'max_f...      184

# %% [markdown]
# ## Train a third model
# - using the full set of vars, the best reduced set from lasso, and the best reduced set from GBT
# - see if our reductions generalized well enough to be useful for another estimator

# %%
lasso_reduced = coef_fi_lasso.loc[coef_fi_lasso['feature'] != 0].index.to_list()
gbt_reduced = f.history['gbt_pfi_reduced']['Xvars']

# %%
f.set_estimator('xgboost')
print('finding optimal hyperparams')
f.ingest_grid(grids['xgboost'])
f.tune()
print('training first model - all xvars')
f.auto_forecast(
    **model_params,
    call_me = 'xgboost_all_vars',
)
print('training second model - lasso xvars only')
f.manual_forecast(
    **model_params,
    **f.best_params,
    Xvars = lasso_reduced,
    call_me = 'xgboost_lasso_reduced_vars',
)
print('training third model - gbt xvars only')
f.manual_forecast(
    **model_params,
    **f.best_params,
    Xvars = gbt_reduced,
    call_me = 'xgboost_gbt_reduced_vars',
)

# %% [markdown]
# ## Benchmark models
# - since none of these were dynamically tested, all their metrics represent averages of several 1-step forecast
# - we will use these metrics to decide about which four models performed best

# %%
export_results(f)
# Out:
#                 ModelNickname  TestSetMAE  InSampleMAE  TestSetR2  InSampleR2  \
# 0            xgboost_all_vars     25.1171       0.0003     0.6526      1.0000
# 1             gbt_pfi_reduced     25.0820       0.7737     0.6504      0.9998
# 2            gbt_gini_reduced     30.4877       0.7882     0.4983      0.9998
# 3  xgboost_lasso_reduced_vars     38.8688       0.0003     0.1510      1.0000
# 4                       lasso     45.5011      17.3371     0.1459      0.8818
# 5          lasso_coef_reduced     45.5250      17.3361     0.1450      0.8818
# 6           lasso_pfi_reduced     45.5266      17.3365     0.1447      0.8818
# 7    xgboost_gbt_reduced_vars     38.1007       0.0003     0.1311      1.0000
# 8                         gbt     43.8911       0.7833    -0.3013      0.9998
#
#                                          HyperParams  N_Xvars
# 0  {'n_estimators': 10000, 'subsample': 0.9, 'max...      184
# 1  {'n_estimators': 10000, 'max_depth': 2, 'max_f...      172
# 2  {'n_estimators': 10000, 'max_depth': 2, 'max_f...      176
# 3  {'n_estimators': 10000, 'subsample': 0.9, 'max...      106
# 4                                   {'alpha': 0.025}      184
# 5                                   {'alpha': 0.025}      177
# 6                                   {'alpha': 0.025}      173
# 7  {'n_estimators': 10000, 'subsample': 0.9, 'max...      172
# 8  {'n_estimators': 10000, 'max_depth': 2, 'max_f...      184

# %%
best_models = [
    'xgboost_all_vars',
    'gbt_pfi_reduced',
    'gbt_gini_reduced',
    'xgboost_lasso_reduced_vars',
    'lasso',
]

# %%
f.plot_test_set(
    ci=True,
    models=best_models,
    include_train=False,
    order_by='LevelTestSetMAE'
)
plt.show()

# %% [markdown]
# ## Backtest models
# - since models were not dynamically tested, we may want to know how they could perform in a dynamic multi-step process
# - to do that, we backtest a 120-period forecast over the last 25 horizons in the dataset
# - the best model from this step we can call our actual best model

# %%
backtest_metrics = {}

for model in best_models:
    print(f'backtesting {model}')
    f.backtest(model,n_iter=25,fcst_length=240)
    backtest_metrics[model] = f.export_backtest_metrics(model)
# Out:
# backtesting lasso
# backtesting lasso_coef_reduced
# backtesting lasso_pfi_reduced
# backtesting gbt
# backtesting gbt_gini_reduced
# backtesting gbt_pfi_reduced
# backtesting xgboost_all_vars
# backtesting xgboost_lasso_reduced_vars
# backtesting xgboost_gbt_reduced_vars

# %%
all_metrics = pd.DataFrame(index=backtest_metrics[model].index)
for model in best_models:
    all_metrics[model] = backtest_metrics[model]['mean']

# %%
backtest_metrics[best_models[-1]]
# Out:
#        iter1   iter2    iter3   iter4    iter5   iter6   iter7   iter8  \
# RMSE 36.1077 24.6237 148.7010 47.4169 131.7060 43.5749 35.8953 27.7497
# MAE  26.4906 17.9489 123.1708 37.4163 109.7902 31.2028 27.8931 21.6066
# R2    0.5335  0.7847  -6.7790  0.2199  -4.9750  0.3516  0.5674  0.7522
# MAPE     NaN     NaN      NaN     NaN      NaN     NaN     NaN     NaN
#
#        iter9  iter10  ...  iter17  iter18  iter19  iter20  iter21  iter22  \
# RMSE 46.9166 36.3244  ... 43.8500 72.0271 48.4586 74.3446 29.8485 40.6892
# MAE  38.1509 26.9666  ... 30.6261 47.7699 33.4368 55.6053 21.1186 31.8856
# R2    0.3037  0.5864  ...  0.4382 -0.5210  0.3124 -0.6058  0.7456  0.5287
# MAPE     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#       iter23  iter24  iter25    mean
# RMSE 41.4500 37.5423 48.1090 53.0421
# MAE  34.0880 27.9243 36.2762 40.8483
# R2    0.5091  0.5960  0.3331 -0.1876
# MAPE     NaN     NaN     NaN     NaN
#
# [4 rows x 26 columns]

# %%
all_metrics
# Out:
#        lasso  lasso_coef_reduced  lasso_pfi_reduced     gbt  gbt_gini_reduced  \
# RMSE 49.5029             49.5012            49.4962 87.6055           98.9940
# MAE  44.1803             44.1796            44.1748 74.3269           85.0945
# R2    0.2342              0.2342             0.2344 -2.5307           -3.2209
# MAPE     NaN                 NaN                NaN     NaN               NaN
#
#       gbt_pfi_reduced  xgboost_all_vars  xgboost_lasso_reduced_vars  \
# RMSE         103.3987           50.0811                     50.7615
# MAE           87.8266           37.3595                     39.0811
# R2            -3.3088            0.0484                      0.0936
# MAPE              NaN               NaN                         NaN
#
#       xgboost_gbt_reduced_vars
# RMSE                   53.0421
# MAE                    40.8483
# R2                     -0.1876
# MAPE                       NaN

# %%
best_model = 'xgboost_all_vars'

# %% [markdown]
# ## Retrain the best model with dynamic testing
# - This way, we can see how the model would have actually performed on the multi-step test set

# %%
best_model_estimator = results.loc[results['ModelNickname'] == best_model,'Estimator'].values[0]
best_model_hyperparams = results.loc[results['ModelNickname'] == best_model,'HyperParams'].values[0]
best_model_xvars = results.loc[results['ModelNickname'] == best_model,'Xvars'].values[0]

# %%
prepare_fcst(f,test_length=240,fcst_length=240)
f.set_estimator(best_model_estimator)
f.manual_forecast(
    **best_model_hyperparams,
    Xvars=best_model_xvars,
    call_me=best_model+'_dynamically_tested',
)

# %%
f.plot_test_set(models = best_model+'_dynamically_tested',ci=True,include_train=False)
plt.show()

# %%
f.plot(models=best_model+'_dynamically_tested')
plt.show()

# %%
best_model_results = f.export('model_summaries',models=best_model+'_dynamically_tested')
best_model_results[['TestSetRMSE','TestSetR2','InSampleRMSE','InSampleR2']]
# Out:
#    TestSetRMSE  TestSetR2  InSampleRMSE  InSampleR2
# 0      39.1498     0.4516        0.0004      1.0000
