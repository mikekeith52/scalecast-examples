# %%
{'xgboost':dict(
    n_estimators=[2000,5000,10000],
    subsample=[0.8,0.9],
    max_depth=[1,2,3,6], 
)}

# %% [markdown]
# ## Reducing with XGBoost

# %%
f.set_estimator('xgboost')
f.ingest_grid(grids['xgboost'])
f.tune()
f.auto_forecast(**model_params)
f.save_feature_importance()

# %%
pfi_fi_xgboost = f.export_feature_importance('xgboost').reset_index()

reduce_vars(
    f,
    pfi_fi_xgboost,
    'xgboost_pfi_reduced',
    patience=5,
    monitor="TestSetRMSE",
)
# Out:
# beginning TestSetRMSE metric value: 26.90168718897764
# dropping cycle132sin
# dropping AR93
# dropping AR85
# dropping AR104
# dropping AR29
# final model trained with 179 variables
# no improvement made with feature reduction

# %%
export_results(f)
# Out:
#           ModelNickname         TestSetRMSE  InSampleRMSE  \
# 0                 lasso             25.5482       23.7973
# 1               xgboost             26.9017        0.0003
# 2                   gbt             28.4293        0.0022
# 3       gbt_pfi_reduced             71.5184        0.0021
# 4      gbt_gini_reduced             78.1102        0.0020
# 5   xgboost_pfi_reduced            108.4637        0.0004
# 6                   mlr           1068.2933       23.4756
# 7    lasso_coef_reduced           1504.4396       23.7974
# 8     lasso_pfi_reduced           8187.4196       28.3338
# 9      mlr_pfi_reduced1  3181539987170.9668       33.6840
# 10     mlr_pfi_reduced2 12982958698836.6152       28.2464
# 11      mlr_pfi_reduced 29133619050820.1172       27.5971
#
#                         TestSetR2  InSampleR2  \
# 0                          0.8639      0.8820
# 1                          0.8491      1.0000
# 2                          0.8315      1.0000
# 3                         -0.0662      1.0000
# 4                         -0.2718      1.0000
# 5                         -1.4523      1.0000
# 6                       -236.8941      0.8852
# 7                       -470.7937      0.8820
# 8                     -13972.2264      0.8327
# 9    -2109975308996670128128.0000      0.7636
# 10  -35135808562227792838656.0000      0.8337
# 11 -176925925212836272799744.0000      0.8413
#
#                                           HyperParams  N_Xvars
# 0                                     {'alpha': 0.01}      184
# 1   {'n_estimators': 10000, 'subsample': 0.9, 'max...      184
# 2   {'n_estimators': 10000, 'max_depth': 3, 'max_f...      184
# 3   {'n_estimators': 10000, 'max_depth': 3, 'max_f...      179
# 4   {'n_estimators': 10000, 'max_depth': 3, 'max_f...      179
# 5   {'n_estimators': 10000, 'subsample': 0.9, 'max...      179
# 6                                                  {}      184
# 7                                     {'alpha': 0.01}      179
# 8                                     {'alpha': 0.01}      179
# 9                                                  {}       89
# 10                                                 {}      177
# 11                                                 {}      179
