# %% [markdown]
# # Silverkite Example
# Silverkite is a model from the greykite package, developed by LinkedIn. It is considered an automated modeling procedure, like Facebook Prophet. It has its own database of holidays it forecasts with and attempts to tune its parameters automatically. The model itself is a type of linear regression with changepoints and regularization.
# In this notebook, the following concepts are covered:
# 1. Loading Forecaster objects with external regressors
# 2. Forecasting with default silverkite model
# 3. Modifying changepoints in silverkite model
# 4. Tuning silverkite model
# 5. Forecasting on differenced data
# 6. Model summaries
#
# - required package to run model: `!pip install greykite` (this is a big package)
# - read more about grekite: https://engineering.linkedin.com/blog/2021/greykite--a-flexible--intuitive--and-fast-forecasting-library
# - see the [combo](https://scalecast-examples.readthedocs.io/en/latest/combo/combo.html) notebook for an overview of this dataset with EDA

# %%
import pandas as pd
import pandas_datareader as pdr
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil.relativedelta import relativedelta
from scalecast.Forecaster import Forecaster

sns.set(rc={'figure.figsize':(12,8)})

# %%
df = pdr.get_data_fred(['HOUSTNSA','JHDUSRGDPBR'],start='1900-01-01',end='2021-12-31')
df['JHDUSRGDPBR'] = df['JHDUSRGDPBR'].fillna(method='ffill').fillna(0)
f = Forecaster(y=df['HOUSTNSA'],current_dates=df.index)
f
# Out:
# Forecaster(
#     DateStartActuals=1959-01-01T00:00:00.000000000
#     DateEndActuals=2021-12-01T00:00:00.000000000
#     Freq=MS
#     N_actuals=756
#     ForecastLength=0
#     Xvars=[]
#     Differenced=0
#     TestLength=1
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
# )

# %% [markdown]
# ## Prepare Forecast
#
# ### Prepare the Recession Indicator
# - use as an exogenous regressor

# %%
df.head()
# Out:
#             HOUSTNSA  JHDUSRGDPBR
# DATE
# 1959-01-01      96.2          0.0
# 1959-02-01      99.0          0.0
# 1959-03-01     127.7          0.0
# 1959-04-01     150.8          0.0
# 1959-05-01     152.5          0.0

# %%
# prepare recession indicator for future
# assume no future recessions in next two years
recessions = df.reset_index()[['DATE','JHDUSRGDPBR']]
fut_recessions = pd.DataFrame({'DATE':pd.date_range(start=recessions['DATE'].max(),end=recessions['DATE'].max() + relativedelta(months=24),freq='MS').values[1:],
                              'JHDUSRGDPBR':[0]*24})
recessions = pd.concat([recessions,fut_recessions])
recessions.tail()
# Out:
#          DATE  JHDUSRGDPBR
# 19 2023-08-01          0.0
# 20 2023-09-01          0.0
# 21 2023-10-01          0.0
# 22 2023-11-01          0.0
# 23 2023-12-01          0.0

# %% [markdown]
# ### Load Object with Parameters and Regressors
# - Forecast length: 24 periods (two years)
# - Test length: 10%
# - External recession indicator
# - 1,000 bootstrap samples for more accurate confidence intervals

# %%
f.generate_future_dates(24)
f.set_test_length(.1)
f.ingest_Xvars_df(recessions,date_col="DATE")
f.set_bootstrap_samples(1000)
f
# Out:
# Forecaster(
#     DateStartActuals=1959-01-01T00:00:00.000000000
#     DateEndActuals=2021-12-01T00:00:00.000000000
#     Freq=MS
#     N_actuals=756
#     ForecastLength=24
#     Xvars=['JHDUSRGDPBR']
#     Differenced=0
#     TestLength=75
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=1000
#     CurrentEstimator=None
# )

# %% [markdown]
# ## Apply the silverkite model
#
# ### Default parameters
# - by default, silverkite will attempt to add its own seasonality, lags, and other model parameters
# - in the underlying package, these parameters are validated with cross-validation, but in scalecast that feature is disabled for faster runtimes

# %%
f.set_estimator('silverkite')
f.manual_forecast(call_me='silverkite1')

# %% [markdown]
# After running this model, for some environments, it is necessary to reset some matplotlib parameters or else plots won't display.

# %%
matplotlib.use("nbAgg")
# %matplotlib inline
sns.set(rc={'figure.figsize':(12,8)})

# %% [markdown]
# Now we can see the results on the test set.

# %%
f.plot_test_set(ci=True,models='silverkite1')
plt.title('Default Silverkite Test Results',size=16)
plt.show()

# %% [markdown]
# ### Adding Xvars and Changepoints
#
# By default, this model did not pick up seasonality well at all. Let's try giving it the recession indicator to forecast with to see if that helps. We can also change the changepoints parameter to 5 as there appears to be about that many changes in the data's history.

# %%
f.manual_forecast(Xvars=['JHDUSRGDPBR'],changepoints=5,call_me='silverkite2')

# %%
matplotlib.use("nbAgg")
# %matplotlib inline
sns.set(rc={'figure.figsize':(12,8)})

# %% [markdown]
# Now we can see the results on the test set.

# %%
f.plot_test_set(ci=True,models='silverkite2')
plt.title('Silverkite Xvars and CPs Test Results',size=16)
plt.show()

# %% [markdown]
# ### Tuning Hyperparameters
#
# That didn't seem to make much if any difference on the dataset. We can try cycling through more changepoints to see if that helps.
#
# First, we set aside 12 validation periods to do that. Then, we create a grid that is of `dict` type, ingest the grid, tune the model with it on those 12 periods, and forecast with the best-performing selected hyperparameters. We change the validation metric to R2 to see if that helps it pick up more seasonality.

# %%
f.set_validation_length(12)
f.set_validation_metric('r2')
grid = {'changepoints':range(7)}
f.ingest_grid(grid)
f.tune()
f.auto_forecast(call_me='silverkite3')

# %%
matplotlib.use("nbAgg")
# %matplotlib inline
sns.set(rc={'figure.figsize':(12,8)})

# %%
f.plot_test_set(ci=True,models='silverkite3')
plt.title('Tuned Silverkite Test Results',size=16)
plt.show()

# %% [markdown]
# ### Data Differencing
#
# That didn't work as well as we were hoping, but we do have one last trick: forecasting on differenced data.

# %%
f.diff() # raises an error if you run twice

# %%
f.manual_forecast(call_me='silverkite4')

# %%
matplotlib.use("nbAgg")
# %matplotlib inline
sns.set(rc={'figure.figsize':(12,8)})

# %%
f.plot_test_set(ci=True,models='silverkite4')
plt.title('Diffed Silverkite Test Results',size=16)
plt.show()

# %% [markdown]
# That gave us results on the differenced series, but, it is nice to always have results at the original forecast's level. Note that confidence intervals are no longer available when plotting a model that was forecasted on a differenced series at its original level.

# %%
f.plot_test_set(models='silverkite4',level=True)
plt.title('Diffed Silverkite Test Results - Level',size=16)
plt.show()

# %% [markdown]
# ## Model Summaries
#
# It seems like that worked, at least as far as being able to capture seasonality. It is still not the best model for this series, but silverkite can work well for other series. We can now look at these models' forecasts to future periods. Note, all models are plotted at the original data level.

# %%
f.plot()
plt.title('All models future forecasts')
plt.show()

# %% [markdown]
# Here is some error information about each model:

# %%
pd.set_option('display.float_format',  '{:.4f}'.format)
ms = f.export('model_summaries',determine_best_by='LevelTestSetRMSE')
ms[
    [
        'ModelNickname',
        'LevelTestSetRMSE',
        'TestSetRMSE',
        'InSampleRMSE',
        'Xvars',
        'HyperParams'
    ]
]
# Out:
#   ModelNickname  LevelTestSetRMSE  TestSetRMSE  InSampleRMSE          Xvars  \
# 0   silverkite3           18.5741      18.5741       36.7472           None
# 1   silverkite2           18.5741      18.5741       36.7472  [JHDUSRGDPBR]
# 2   silverkite1           18.5741      18.5741       36.7472           None
# 3   silverkite4           20.4133      12.3925       15.8891           None
#
#            HyperParams
# 0  {'changepoints': 0}
# 1  {'changepoints': 5}
# 2                   {}
# 3                   {}

# %% [markdown]
# Although our last model looked the most able to predict seasonality, it technically had worse out-of-sample RMSE than the other models. It did fit the underlying data the best, however, considering the InSampleRMSE.
#
# Below is an example of how to save and extract summary stats directly from the greykite library.

# %%
f.save_summary_stats()
f.export_summary_stats('silverkite4')
# Out:
#                                                     Estimate  Std. Err  \
# Pred_col
# Intercept                                             2.5693    1.4512
# C(Q('events_Chinese New Year'), levels=['', 'ev...    0.0092    0.3347
# C(Q('events_Chinese New Year_minus_1'), levels=...    0.2057    0.4617
# C(Q('events_Chinese New Year_minus_2'), levels=...   -0.4007    0.4694
# C(Q('events_Chinese New Year_plus_1'), levels=[...   -0.0946    0.3547
# C(Q('events_Chinese New Year_plus_2'), levels=[...   -0.0789    0.3538
# C(Q('events_Christmas Day'), levels=['', 'event...    0.0000    0.0000
# C(Q('events_Christmas Day_minus_1'), levels=[''...    0.0000    0.0000
# C(Q('events_Christmas Day_minus_2'), levels=[''...    0.0000    0.0000
# C(Q('events_Christmas Day_plus_1'), levels=['',...    0.0000    0.0000
# C(Q('events_Christmas Day_plus_2'), levels=['',...    0.0000    0.0000
# C(Q('events_Good Friday'), levels=['', 'event']...    0.5547    0.4608
# C(Q('events_Good Friday_minus_1'), levels=['', ...   -0.0035    0.1760
# C(Q('events_Good Friday_minus_2'), levels=['', ...    0.6699    0.6240
# C(Q('events_Good Friday_plus_1'), levels=['', '...    0.2406    0.1707
# C(Q('events_Good Friday_plus_2'), levels=['', '...    0.3464    0.3447
# C(Q('events_Independence Day'), levels=['', 'ev...    0.0000    0.0000
# C(Q('events_Independence Day_minus_1'), levels=...    0.0000    0.0000
# C(Q('events_Independence Day_minus_2'), levels=...    0.0000    0.0000
# C(Q('events_Independence Day_plus_1'), levels=[...    0.0000    0.0000
# C(Q('events_Independence Day_plus_2'), levels=[...    0.0000    0.0000
# C(Q('events_Labor Day'), levels=['', 'event'])[...    3.1464    0.8410
# C(Q('events_Labor Day_minus_1'), levels=['', 'e...   -1.4307    0.5659
# C(Q('events_Labor Day_minus_2'), levels=['', 'e...   -2.6876    1.1280
# C(Q('events_Labor Day_plus_1'), levels=['', 'ev...    0.0000    0.0000
# C(Q('events_Labor Day_plus_2'), levels=['', 'ev...    0.0000    0.0000
# C(Q('events_Memorial Day'), levels=['', 'event'...    0.0000    0.0000
# C(Q('events_Memorial Day_minus_1'), levels=['',...    0.0000    0.0000
# C(Q('events_Memorial Day_minus_2'), levels=['',...    0.0000    0.0000
# C(Q('events_Memorial Day_plus_1'), levels=['', ...    0.4057    0.5093
# C(Q('events_Memorial Day_plus_2'), levels=['', ...   -1.4754    0.6088
# C(Q('events_New Years Day'), levels=['', 'event...    0.0097    0.8396
# C(Q('events_New Years Day_minus_1'), levels=[''...    0.0000    0.0000
# C(Q('events_New Years Day_minus_2'), levels=[''...    0.0000    0.0000
# C(Q('events_New Years Day_plus_1'), levels=['',...    0.0000    0.0000
# C(Q('events_New Years Day_plus_2'), levels=['',...    0.0000    0.0000
# C(Q('events_Other'), levels=['', 'event'])[T.ev...   -3.1918    0.8641
# C(Q('events_Other_minus_1'), levels=['', 'event...   -6.0949    0.9690
# C(Q('events_Other_minus_2'), levels=['', 'event...    4.3143    0.9605
# C(Q('events_Other_plus_1'), levels=['', 'event'...   -6.6824    1.1244
# C(Q('events_Other_plus_2'), levels=['', 'event'...    1.4598    0.9939
# C(Q('events_Thanksgiving'), levels=['', 'event'...    0.0000    0.0000
# C(Q('events_Thanksgiving_minus_1'), levels=['',...    0.0000    0.0000
# C(Q('events_Thanksgiving_minus_2'), levels=['',...    0.0000    0.0000
# C(Q('events_Thanksgiving_plus_1'), levels=['', ...    0.0000    0.0000
# C(Q('events_Thanksgiving_plus_2'), levels=['', ...    0.0000    0.0000
# C(Q('events_Veterans Day'), levels=['', 'event'...    0.0000    0.0000
# C(Q('events_Veterans Day_minus_1'), levels=['',...    0.0000    0.0000
# C(Q('events_Veterans Day_minus_2'), levels=['',...    0.0000    0.0000
# C(Q('events_Veterans Day_plus_1'), levels=['', ...    0.0000    0.0000
# C(Q('events_Veterans Day_plus_2'), levels=['', ...    0.0000    0.0000
# ct1                                                   0.0100    0.0311
#
#                                                     Pr(>)_boot sig. code  \
# Pred_col
# Intercept                                               0.0820         .
# C(Q('events_Chinese New Year'), levels=['', 'ev...      0.9760
# C(Q('events_Chinese New Year_minus_1'), levels=...      0.6560
# C(Q('events_Chinese New Year_minus_2'), levels=...      0.3900
# C(Q('events_Chinese New Year_plus_1'), levels=[...      0.7660
# C(Q('events_Chinese New Year_plus_2'), levels=[...      0.8180
# C(Q('events_Christmas Day'), levels=['', 'event...      1.0000
# C(Q('events_Christmas Day_minus_1'), levels=[''...      1.0000
# C(Q('events_Christmas Day_minus_2'), levels=[''...      1.0000
# C(Q('events_Christmas Day_plus_1'), levels=['',...      1.0000
# C(Q('events_Christmas Day_plus_2'), levels=['',...      1.0000
# C(Q('events_Good Friday'), levels=['', 'event']...      0.1380
# C(Q('events_Good Friday_minus_1'), levels=['', ...      0.9800
# C(Q('events_Good Friday_minus_2'), levels=['', ...      0.2080
# C(Q('events_Good Friday_plus_1'), levels=['', '...      0.2100
# C(Q('events_Good Friday_plus_2'), levels=['', '...      0.1680
# C(Q('events_Independence Day'), levels=['', 'ev...      1.0000
# C(Q('events_Independence Day_minus_1'), levels=...      1.0000
# C(Q('events_Independence Day_minus_2'), levels=...      1.0000
# C(Q('events_Independence Day_plus_1'), levels=[...      1.0000
# C(Q('events_Independence Day_plus_2'), levels=[...      1.0000
# C(Q('events_Labor Day'), levels=['', 'event'])[...      0.0000       ***
# C(Q('events_Labor Day_minus_1'), levels=['', 'e...      0.0080        **
# C(Q('events_Labor Day_minus_2'), levels=['', 'e...      0.0200         *
# C(Q('events_Labor Day_plus_1'), levels=['', 'ev...      1.0000
# C(Q('events_Labor Day_plus_2'), levels=['', 'ev...      1.0000
# C(Q('events_Memorial Day'), levels=['', 'event'...      1.0000
# C(Q('events_Memorial Day_minus_1'), levels=['',...      1.0000
# C(Q('events_Memorial Day_minus_2'), levels=['',...      1.0000
# C(Q('events_Memorial Day_plus_1'), levels=['', ...      0.4180
# C(Q('events_Memorial Day_plus_2'), levels=['', ...      0.0100         *
# C(Q('events_New Years Day'), levels=['', 'event...      0.9880
# C(Q('events_New Years Day_minus_1'), levels=[''...      1.0000
# C(Q('events_New Years Day_minus_2'), levels=[''...      1.0000
# C(Q('events_New Years Day_plus_1'), levels=['',...      1.0000
# C(Q('events_New Years Day_plus_2'), levels=['',...      1.0000
# C(Q('events_Other'), levels=['', 'event'])[T.ev...      0.0000       ***
# C(Q('events_Other_minus_1'), levels=['', 'event...      0.0000       ***
# C(Q('events_Other_minus_2'), levels=['', 'event...      0.0000       ***
# C(Q('events_Other_plus_1'), levels=['', 'event'...      0.0000       ***
# C(Q('events_Other_plus_2'), levels=['', 'event'...      0.1460
# C(Q('events_Thanksgiving'), levels=['', 'event'...      1.0000
# C(Q('events_Thanksgiving_minus_1'), levels=['',...      1.0000
# C(Q('events_Thanksgiving_minus_2'), levels=['',...      1.0000
# C(Q('events_Thanksgiving_plus_1'), levels=['', ...      1.0000
# C(Q('events_Thanksgiving_plus_2'), levels=['', ...      1.0000
# C(Q('events_Veterans Day'), levels=['', 'event'...      1.0000
# C(Q('events_Veterans Day_minus_1'), levels=['',...      1.0000
# C(Q('events_Veterans Day_minus_2'), levels=['',...      1.0000
# C(Q('events_Veterans Day_plus_1'), levels=['', ...      1.0000
# C(Q('events_Veterans Day_plus_2'), levels=['', ...      1.0000
# ct1                                                     0.7560
#
#                                                                                            95%CI
# Pred_col
# Intercept                                                [-0.2747466006938516, 5.58452747001032]
# C(Q('events_Chinese New Year'), levels=['', 'ev...     [-0.5903899978438698, 0.7103931221383426]
# C(Q('events_Chinese New Year_minus_1'), levels=...      [-0.6432502136204177, 1.067757726498427]
# C(Q('events_Chinese New Year_minus_2'), levels=...     [-1.3127284417771055, 0.5307743832672385]
# C(Q('events_Chinese New Year_plus_1'), levels=[...      [-0.779632199054938, 0.6122396387494318]
# C(Q('events_Chinese New Year_plus_2'), levels=[...     [-0.7877564854225234, 0.6018806650768074]
# C(Q('events_Christmas Day'), levels=['', 'event...                                    [0.0, 0.0]
# C(Q('events_Christmas Day_minus_1'), levels=[''...                                    [0.0, 0.0]
# C(Q('events_Christmas Day_minus_2'), levels=[''...                                    [0.0, 0.0]
# C(Q('events_Christmas Day_plus_1'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Christmas Day_plus_2'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Good Friday'), levels=['', 'event']...                     [0.0, 1.5692010147316733]
# C(Q('events_Good Friday_minus_1'), levels=['', ...    [-0.34316881205863925, 0.3626473825341532]
# C(Q('events_Good Friday_minus_2'), levels=['', ...                     [0.0, 1.9366511445582344]
# C(Q('events_Good Friday_plus_1'), levels=['', '...                     [0.0, 0.6163114112851249]
# C(Q('events_Good Friday_plus_2'), levels=['', '...                     [0.0, 1.1238244375326254]
# C(Q('events_Independence Day'), levels=['', 'ev...                                    [0.0, 0.0]
# C(Q('events_Independence Day_minus_1'), levels=...                                    [0.0, 0.0]
# C(Q('events_Independence Day_minus_2'), levels=...                                    [0.0, 0.0]
# C(Q('events_Independence Day_plus_1'), levels=[...                                    [0.0, 0.0]
# C(Q('events_Independence Day_plus_2'), levels=[...                                    [0.0, 0.0]
# C(Q('events_Labor Day'), levels=['', 'event'])[...        [1.510847426960677, 4.812116618371864]
# C(Q('events_Labor Day_minus_1'), levels=['', 'e...     [-2.567498337568953, -0.3791517363185242]
# C(Q('events_Labor Day_minus_2'), levels=['', 'e...    [-5.1674346719023845, -0.8149656233505412]
# C(Q('events_Labor Day_plus_1'), levels=['', 'ev...                                    [0.0, 0.0]
# C(Q('events_Labor Day_plus_2'), levels=['', 'ev...                                    [0.0, 0.0]
# C(Q('events_Memorial Day'), levels=['', 'event'...                                    [0.0, 0.0]
# C(Q('events_Memorial Day_minus_1'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Memorial Day_minus_2'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Memorial Day_plus_1'), levels=['', ...     [-0.5592579501496902, 1.4915379735152663]
# C(Q('events_Memorial Day_plus_2'), levels=['', ...     [-2.731276936156844, -0.3677446520637446]
# C(Q('events_New Years Day'), levels=['', 'event...      [-1.702660121104595, 1.6906113550134734]
# C(Q('events_New Years Day_minus_1'), levels=[''...                                    [0.0, 0.0]
# C(Q('events_New Years Day_minus_2'), levels=[''...                                    [0.0, 0.0]
# C(Q('events_New Years Day_plus_1'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_New Years Day_plus_2'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Other'), levels=['', 'event'])[T.ev...     [-4.866370397243594, -1.5135595304366947]
# C(Q('events_Other_minus_1'), levels=['', 'event...     [-7.9992067152148865, -4.306145094578335]
# C(Q('events_Other_minus_2'), levels=['', 'event...        [2.240225326475992, 6.111348750407476]
# C(Q('events_Other_plus_1'), levels=['', 'event'...      [-8.788431888504471, -4.529423506838652]
# C(Q('events_Other_plus_2'), levels=['', 'event'...    [-0.35252843164904923, 3.5113144912052014]
# C(Q('events_Thanksgiving'), levels=['', 'event'...                                    [0.0, 0.0]
# C(Q('events_Thanksgiving_minus_1'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Thanksgiving_minus_2'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Thanksgiving_plus_1'), levels=['', ...                                    [0.0, 0.0]
# C(Q('events_Thanksgiving_plus_2'), levels=['', ...                                    [0.0, 0.0]
# C(Q('events_Veterans Day'), levels=['', 'event'...                                    [0.0, 0.0]
# C(Q('events_Veterans Day_minus_1'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Veterans Day_minus_2'), levels=['',...                                    [0.0, 0.0]
# C(Q('events_Veterans Day_plus_1'), levels=['', ...                                    [0.0, 0.0]
# C(Q('events_Veterans Day_plus_2'), levels=['', ...                                    [0.0, 0.0]
# ct1                                                 [-0.051548960242012706, 0.06858082034547464]

# %% [markdown]
# Contributions related to understanding and improving this model are welcome.
