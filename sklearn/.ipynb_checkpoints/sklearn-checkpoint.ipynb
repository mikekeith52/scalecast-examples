# %% [markdown]
# # Sklearn Example
# This notebook showcases the scalecast wrapper around scikit-learn models. The following concepts are overviewed:
#
# 1. Modeling with MLR
# 2. Regularization of linear models
# 3. Ensemble Modeling with Random Forest, XGBoost, LightGBM, Bagging, and Stacking
# 4. Model Benchmarking
# 5. Results visualization
# 6. Feature importance
#
# The data is available for download here: https://www.kaggle.com/datasets/bobnau/daily-website-visitors
# See the blog post: https://medium.com/towards-data-science/expand-your-time-series-arsenal-with-these-models-10c807d37558

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil.relativedelta import relativedelta
from scalecast.Forecaster import Forecaster
from scalecast import GridGenerator
from tqdm.notebook import tqdm

# sklearn imports for the bagging and stacking models
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

sns.set(rc={'figure.figsize':(12,8)})
pd.set_option('max_colwidth',500)
pd.set_option('display.max_rows',500)

# %%
def plot_test_export_summaries(f):
    """ exports the relevant statisitcal information and displays a plot of the test-set results for the last model run
    """
    f.plot_test_set(models=f.estimator,ci=True)
    plt.title(f'{f.estimator} test-set results',size=16)
    plt.show()
    return f.export('model_summaries',determine_best_by='TestSetMAPE')[
        [
            'ModelNickname',
            'HyperParams',
            'TestSetMAPE',
            'TestSetR2',
            'InSampleMAPE',
            'InSampleR2'
        ]
    ]

# %% [markdown]
# We will bring in the default grids from scalecast and tune some of our models this way. For others, we will create our own grids.

# %%
GridGenerator.get_example_grids()

# %%
data = pd.read_csv('daily-website-visitors.csv')
data.head()
# Out:
#    Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0    1     Sunday            1  9/14/2014      2,146         1,582
# 1    2     Monday            2  9/15/2014      3,621         2,528
# 2    3    Tuesday            3  9/16/2014      3,698         2,630
# 3    4  Wednesday            4  9/17/2014      3,667         2,614
# 4    5   Thursday            5  9/18/2014      3,316         2,366
#
#    First.Time.Visits Returning.Visits
# 0               1430              152
# 1               2297              231
# 2               2352              278
# 3               2327              287
# 4               2130              236

# %%
data.shape
# Out:
# (2167, 8)

# %%
f=Forecaster(y=data['First.Time.Visits'],current_dates=data['Date'])
f.plot()
plt.title('Orig Series',size=16)
plt.show()

# %% [markdown]
# Not all models we will showcase come standard in scalecast, but we can easily add them by using the code below:

# %%
f.add_sklearn_estimator(Lasso,'lasso')
f.add_sklearn_estimator(Ridge,'ridge')
f.add_sklearn_estimator(BaggingRegressor,'bagging')
f.add_sklearn_estimator(StackingRegressor,'stacking')

# %% [markdown]
# For more EDA on this dataset, see the prophet example: https://scalecast-examples.readthedocs.io/en/latest/prophet/prophet.html#EDA

# %% [markdown]
# ## Prepare Forecast
# - 60-day forecast horizon
# - 20% test split
# - 60-period validation split for model tuning
# - add time series regressors:
# - 7 autoregressive terms
#   - 4 seasonal autoregressive terms spaced 7-periods apart
#   - month, quarter, week, and day of year with a fournier transformation
#   - dayofweek, leap year, and week as dummy variables
#   - year

# %%
f.generate_future_dates(60)
f.set_test_length(.2)
f.set_validation_length(60)
f.add_ar_terms(7)
f.add_AR_terms((4,7))
f.add_seasonal_regressors('month','quarter','week','dayofyear',raw=False,sincos=True)
f.add_seasonal_regressors('dayofweek','is_leap_year','week',raw=False,dummy=True,drop_first=True)
f.add_seasonal_regressors('year')
f
# Out:
# Forecaster(
#     DateStartActuals=2014-09-14T00:00:00.000000000
#     DateEndActuals=2020-08-19T00:00:00.000000000
#     Freq=D
#     N_actuals=2167
#     ForecastLength=60
#     Xvars=['AR1', 'AR2', 'AR3', 'AR4', 'AR5', 'AR6', 'AR7', 'AR14', 'AR21', 'AR28', 'monthsin', 'monthcos', 'quartersin', 'quartercos', 'weeksin', 'weekcos', 'dayofyearsin', 'dayofyearcos', 'dayofweek_1', 'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5', 'dayofweek_6', 'is_leap_year_True', 'week_10', 'week_11', 'week_12', 'week_13', 'week_14', 'week_15', 'week_16', 'week_17', 'week_18', 'week_19', 'week_2', 'week_20', 'week_21', 'week_22', 'week_23', 'week_24', 'week_25', 'week_26', 'week_27', 'week_28', 'week_29', 'week_3', 'week_30', 'week_31', 'week_32', 'week_33', 'week_34', 'week_35', 'week_36', 'week_37', 'week_38', 'week_39', 'week_4', 'week_40', 'week_41', 'week_42', 'week_43', 'week_44', 'week_45', 'week_46', 'week_47', 'week_48', 'week_49', 'week_5', 'week_50', 'week_51', 'week_52', 'week_53', 'week_6', 'week_7', 'week_8', 'week_9', 'year']
#     Differenced=0
#     TestLength=433
#     ValidationLength=60
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
# )

# %% [markdown]
# ## MLR
# - use default parameters (which means all input vars are scaled with a minmax scaler by default for all sklearn models)

# %%
f.set_estimator('mlr')
f.manual_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname HyperParams  TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0           mlr          {}     0.127598    0.76302      0.064186    0.953483

# %% [markdown]
# ## Lasso
# - tune alpha with 100 choices

# %%
f.set_estimator('lasso')
lasso_grid = {'alpha':np.linspace(0,2,100)}
f.ingest_grid(lasso_grid)
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname                     HyperParams  TestSetMAPE  TestSetR2  \
# 0           mlr                              {}     0.127598   0.763020
# 1         lasso  {'alpha': 0.08080808080808081}     0.139291   0.746174
#
#    InSampleMAPE  InSampleR2
# 0      0.064186    0.953483
# 1      0.064569    0.953145

# %% [markdown]
# ## Ridge
# - tune alpha with the same grid used for lasso

# %%
f.set_estimator('ridge')
f.ingest_grid(lasso_grid)
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname                     HyperParams  TestSetMAPE  TestSetR2  \
# 0           mlr                              {}     0.127598   0.763020
# 1         lasso  {'alpha': 0.08080808080808081}     0.139291   0.746174
# 2         ridge  {'alpha': 0.38383838383838387}     0.141175   0.742751
#
#    InSampleMAPE  InSampleR2
# 0      0.064186    0.953483
# 1      0.064569    0.953145
# 2      0.064402    0.953154

# %% [markdown]
# ## Elasticnet
#
# - this model mixes L1 and L2 regularization parameters
# - its default grid is pretty good for finding the optimal alpha value

# %%
f.set_estimator('elasticnet')
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname                      HyperParams  TestSetMAPE  TestSetR2  \
# 0           mlr                               {}     0.127598   0.763020
# 1         lasso   {'alpha': 0.08080808080808081}     0.139291   0.746174
# 2    elasticnet  {'alpha': 0.3, 'l1_ratio': 1.0}     0.140075   0.744008
# 3         ridge   {'alpha': 0.38383838383838387}     0.141175   0.742751
#
#    InSampleMAPE  InSampleR2
# 0      0.064186    0.953483
# 1      0.064569    0.953145
# 2      0.064471    0.953209
# 3      0.064402    0.953154

# %% [markdown]
# ## RF
# - create a grid to tune Random Forest with more options than what is available in the default grids

# %%
f.set_estimator('rf')
rf_grid = {
    'max_depth':[2,3,4,5],
    'n_estimators':[100,200,500],
    'max_features':['auto','sqrt','log2'],
    'max_samples':[.75,.9,1],
}
f.ingest_grid(rf_grid)
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0           mlr
# 1         lasso
# 2    elasticnet
# 3         ridge
# 4            rf
#
#                                                                           HyperParams  \
# 0                                                                                  {}
# 1                                                      {'alpha': 0.08080808080808081}
# 2                                                     {'alpha': 0.3, 'l1_ratio': 1.0}
# 3                                                      {'alpha': 0.38383838383838387}
# 4  {'max_depth': 5, 'n_estimators': 500, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.127598   0.763020      0.064186    0.953483
# 1     0.139291   0.746174      0.064569    0.953145
# 2     0.140075   0.744008      0.064471    0.953209
# 3     0.141175   0.742751      0.064402    0.953154
# 4     0.314719  -0.876447      0.082940    0.918658

# %% [markdown]
# So far, both using a visual inspection and examing its test-set performance, Random Forest does worse than all others.

# %% [markdown]
# ## XGBoost
# - Build a grid to tune XGBoost

# %%
f.set_estimator('xgboost')
xgboost_grid = {
     'n_estimators':[150,200,250],
     'scale_pos_weight':[5,10],
     'learning_rate':[0.1,0.2],
     'gamma':[0,3,5], 
     'subsample':[0.8,0.9]
}
f.ingest_grid(xgboost_grid)
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           mlr
# 2         lasso
# 3    elasticnet
# 4         ridge
# 5            rf
#
#                                                                                         HyperParams  \
# 0  {'n_estimators': 150, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.9}
# 1                                                                                                {}
# 2                                                                    {'alpha': 0.08080808080808081}
# 3                                                                   {'alpha': 0.3, 'l1_ratio': 1.0}
# 4                                                                    {'alpha': 0.38383838383838387}
# 5                {'max_depth': 5, 'n_estimators': 500, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.123601   0.752776      0.019002    0.995539
# 1     0.127598   0.763020      0.064186    0.953483
# 2     0.139291   0.746174      0.064569    0.953145
# 3     0.140075   0.744008      0.064471    0.953209
# 4     0.141175   0.742751      0.064402    0.953154
# 5     0.314719  -0.876447      0.082940    0.918658

# %% [markdown]
# This is our best model so far using the test MAPE as the metric to determine that by. It appears to be also be highly overfit.

# %% [markdown]
# ## LightGBM
# - Build a grid to tune LightGBM

# %%
f.set_estimator('lightgbm')
lightgbm_grid = {
    'n_estimators':[150,200,250],
    'boosting_type':['gbdt','dart','goss'],
    'max_depth':[1,2,3],
    'learning_rate':[0.001,0.01,0.1],
    'reg_alpha':np.linspace(0,1,5),
    'reg_lambda':np.linspace(0,1,5),
    'num_leaves':np.arange(5,50,5),
}
f.ingest_grid(lightgbm_grid)
f.limit_grid_size(100,random_seed=2)
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           mlr
# 2      lightgbm
# 3         lasso
# 4    elasticnet
# 5         ridge
# 6            rf
#
#                                                                                                                                     HyperParams  \
# 0                                              {'n_estimators': 150, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.9}
# 1                                                                                                                                            {}
# 2  {'n_estimators': 250, 'boosting_type': 'goss', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.25, 'reg_lambda': 1.0, 'num_leaves': 40}
# 3                                                                                                                {'alpha': 0.08080808080808081}
# 4                                                                                                               {'alpha': 0.3, 'l1_ratio': 1.0}
# 5                                                                                                                {'alpha': 0.38383838383838387}
# 6                                                            {'max_depth': 5, 'n_estimators': 500, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.123601   0.752776      0.019002    0.995539
# 1     0.127598   0.763020      0.064186    0.953483
# 2     0.138724   0.664992      0.047422    0.973831
# 3     0.139291   0.746174      0.064569    0.953145
# 4     0.140075   0.744008      0.064471    0.953209
# 5     0.141175   0.742751      0.064402    0.953154
# 6     0.314719  -0.876447      0.082940    0.918658

# %% [markdown]
# ## SGD
# - Use the default Stochastic Gradient Descent grid

# %%
f.set_estimator('sgd')
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           mlr
# 2           sgd
# 3      lightgbm
# 4         lasso
# 5    elasticnet
# 6         ridge
# 7            rf
#
#                                                                                                                                     HyperParams  \
# 0                                              {'n_estimators': 150, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.9}
# 1                                                                                                                                            {}
# 2                                                                               {'penalty': 'l2', 'l1_ratio': 1.0, 'learning_rate': 'constant'}
# 3  {'n_estimators': 250, 'boosting_type': 'goss', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.25, 'reg_lambda': 1.0, 'num_leaves': 40}
# 4                                                                                                                {'alpha': 0.08080808080808081}
# 5                                                                                                               {'alpha': 0.3, 'l1_ratio': 1.0}
# 6                                                                                                                {'alpha': 0.38383838383838387}
# 7                                                            {'max_depth': 5, 'n_estimators': 500, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.123601   0.752776      0.019002    0.995539
# 1     0.127598   0.763020      0.064186    0.953483
# 2     0.134965   0.762446      0.067282    0.949905
# 3     0.138724   0.664992      0.047422    0.973831
# 4     0.139291   0.746174      0.064569    0.953145
# 5     0.140075   0.744008      0.064471    0.953209
# 6     0.141175   0.742751      0.064402    0.953154
# 7     0.314719  -0.876447      0.082940    0.918658

# %% [markdown]
# ## KNN
# - Use the default K-nearest Neighbors grid

# %%
f.set_estimator('knn')
f.tune()
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           mlr
# 2           sgd
# 3           knn
# 4      lightgbm
# 5         lasso
# 6    elasticnet
# 7         ridge
# 8            rf
#
#                                                                                                                                     HyperParams  \
# 0                                              {'n_estimators': 150, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.9}
# 1                                                                                                                                            {}
# 2                                                                               {'penalty': 'l2', 'l1_ratio': 1.0, 'learning_rate': 'constant'}
# 3                                                                                                     {'n_neighbors': 2, 'weights': 'distance'}
# 4  {'n_estimators': 250, 'boosting_type': 'goss', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.25, 'reg_lambda': 1.0, 'num_leaves': 40}
# 5                                                                                                                {'alpha': 0.08080808080808081}
# 6                                                                                                               {'alpha': 0.3, 'l1_ratio': 1.0}
# 7                                                                                                                {'alpha': 0.38383838383838387}
# 8                                                            {'max_depth': 5, 'n_estimators': 500, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.123601   0.752776      0.019002    0.995539
# 1     0.127598   0.763020      0.064186    0.953483
# 2     0.134965   0.762446      0.067282    0.949905
# 3     0.136234   0.712713      0.000000    1.000000
# 4     0.138724   0.664992      0.047422    0.973831
# 5     0.139291   0.746174      0.064569    0.953145
# 6     0.140075   0.744008      0.064471    0.953209
# 7     0.141175   0.742751      0.064402    0.953154
# 8     0.314719  -0.876447      0.082940    0.918658

# %% [markdown]
# KNN is our most overfit model so far, but it fits the test-set pretty well.

# %% [markdown]
# ## BaggingRegressor
# - Like Random Forest is a bagging ensemble model using decision trees, we can use a bagging estimator that uses a three-layered mulit-level perceptron to see if the added complexity improves where the Random Forest couldn't

# %%
f.set_estimator('bagging')
f.manual_forecast(
    base_estimator = MLPRegressor(
        hidden_layer_sizes=(100,100,100)
        ,solver='lbfgs'
    ),
    max_samples = 0.9,
    max_features = 0.5,
)

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       bagging
# 1       xgboost
# 2           mlr
# 3           sgd
# 4           knn
# 5      lightgbm
# 6         lasso
# 7    elasticnet
# 8         ridge
# 9            rf
#
#                                                                                                                                     HyperParams  \
# 0                 {'base_estimator': MLPRegressor(hidden_layer_sizes=(100, 100, 100), solver='lbfgs'), 'max_samples': 0.9, 'max_features': 0.5}
# 1                                              {'n_estimators': 150, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.9}
# 2                                                                                                                                            {}
# 3                                                                               {'penalty': 'l2', 'l1_ratio': 1.0, 'learning_rate': 'constant'}
# 4                                                                                                     {'n_neighbors': 2, 'weights': 'distance'}
# 5  {'n_estimators': 250, 'boosting_type': 'goss', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.25, 'reg_lambda': 1.0, 'num_leaves': 40}
# 6                                                                                                                {'alpha': 0.08080808080808081}
# 7                                                                                                               {'alpha': 0.3, 'l1_ratio': 1.0}
# 8                                                                                                                {'alpha': 0.38383838383838387}
# 9                                                            {'max_depth': 5, 'n_estimators': 500, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.114784   0.793242      0.055682    0.961784
# 1     0.123601   0.752776      0.019002    0.995539
# 2     0.127598   0.763020      0.064186    0.953483
# 3     0.134965   0.762446      0.067282    0.949905
# 4     0.136234   0.712713      0.000000    1.000000
# 5     0.138724   0.664992      0.047422    0.973831
# 6     0.139291   0.746174      0.064569    0.953145
# 7     0.140075   0.744008      0.064471    0.953209
# 8     0.141175   0.742751      0.064402    0.953154
# 9     0.314719  -0.876447      0.082940    0.918658

# %% [markdown]
# This is the best-performing model yet, with less overfitting than XGBoost and KNN.

# %% [markdown]
# ## StackingRegressor
# - This model will use the predictions of other models as inputs to a "final estimator". It's added complexity can mean better performance, although not always.

# %%
f.plot_fitted()
plt.title('all models fitted vals',size=16)
plt.show()

# %% [markdown]
# Sometimes seeing the fitted values can give a good idea of which models to stack, as you want models that can predict both the highs and lows of the series. However, this graph didn't tell us much.
#
# We use four of our best performing models to create the model inputs. We use a bagging estimator as the final model.

# %%
f.set_estimator('stacking')
results = f.export('model_summaries')
estimators = [
    ('knn',
     KNeighborsRegressor(**results.loc[results['ModelNickname'] == 'knn','HyperParams'].values[0])),
    ('xgboost',
     XGBRegressor(**results.loc[results['ModelNickname'] == 'xgboost','HyperParams'].values[0])),
    ('lightgbm',
     LGBMRegressor(**results.loc[results['ModelNickname'] == 'lightgbm','HyperParams'].values[0])),
    ('sgd',
    SGDRegressor(**results.loc[results['ModelNickname'] == 'sgd','HyperParams'].values[0])),
]

final_estimator = BaggingRegressor(
    base_estimator = MLPRegressor(
        hidden_layer_sizes=(100,100,100),
        solver='lbfgs',
    ),
    max_samples = 0.9,
    max_features = 0.5,
)

f.manual_forecast(estimators=estimators,final_estimator=final_estimator)

# %%
plot_test_export_summaries(f)
# Out:
#    ModelNickname  \
# 0       stacking
# 1        bagging
# 2        xgboost
# 3            mlr
# 4            sgd
# 5            knn
# 6       lightgbm
# 7          lasso
# 8     elasticnet
# 9          ridge
# 10            rf
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             HyperParams  \
# 0   {'estimators': [('knn', KNeighborsRegressor(n_neighbors=2, weights='distance')), ('xgboost', XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=0, gpu_id=None,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.1, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=150, n_jobs=None...
# 1                                                                                                                                                                                                                                                                                                                                                                                         {'base_estimator': MLPRegressor(hidden_layer_sizes=(100, 100, 100), solver='lbfgs'), 'max_samples': 0.9, 'max_features': 0.5}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                      {'n_estimators': 150, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.9}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                       {'penalty': 'l2', 'l1_ratio': 1.0, 'learning_rate': 'constant'}
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'n_neighbors': 2, 'weights': 'distance'}
# 6                                                                                                                                                                                                                                                                                                                                                                          {'n_estimators': 250, 'boosting_type': 'goss', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.25, 'reg_lambda': 1.0, 'num_leaves': 40}
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'alpha': 0.08080808080808081}
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {'alpha': 0.3, 'l1_ratio': 1.0}
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'alpha': 0.38383838383838387}
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                   {'max_depth': 5, 'n_estimators': 500, 'max_features': 'auto', 'max_samples': 0.75}
#
#     TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0      0.104163   0.826095      0.045010    0.976229
# 1      0.114784   0.793242      0.055682    0.961784
# 2      0.123601   0.752776      0.019002    0.995539
# 3      0.127598   0.763020      0.064186    0.953483
# 4      0.134965   0.762446      0.067282    0.949905
# 5      0.136234   0.712713      0.000000    1.000000
# 6      0.138724   0.664992      0.047422    0.973831
# 7      0.139291   0.746174      0.064569    0.953145
# 8      0.140075   0.744008      0.064471    0.953209
# 9      0.141175   0.742751      0.064402    0.953154
# 10     0.314719  -0.876447      0.082940    0.918658

# %% [markdown]
# This is our best model with lower amounts of overfitting than some of our other models. We will choose it to make our final forecasts with.

# %% [markdown]
# ## Backtesting
# - Backtesting is an extra step to validate our model's performance. It evaluates the average error over the last n amount of forecast horizons had that particular model been selected to forecast with. Read more about it in the scalecast documentation: https://scalecast.readthedocs.io/en/latest/Forecaster/Forecaster.html#src.scalecast.Forecaster.Forecaster.backtest

# %%
f.backtest('stacking')
# Out:
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations
# Finished loading model, total used 250 iterations

# %% [markdown]
# View the backtest metrics:

# %%
f.export_backtest_metrics('stacking')
# Out:
#            iter1       iter2       iter3      iter4       iter5       iter6  \
# RMSE  238.682521  172.553888  167.254179  177.06195  172.399554  216.854217
# MAE    156.35719  139.235651  135.435819  146.78156  141.232638  172.318298
# R2      0.672882    0.816881    0.829063   0.823458    0.834776     0.73147
# MAPE    0.078551    0.063916    0.062256   0.066885    0.064555    0.076946
#
#            iter7       iter8       iter9      iter10        mean
# RMSE  184.780982  282.914195  199.483464  187.282088  199.926704
# MAE   152.051575  235.631873  157.007313  149.139813  158.519173
# R2      0.807556    0.548817    0.777287    0.807757    0.764995
# MAPE    0.068759    0.104086    0.068694    0.066808    0.072146

# %% [markdown]
# And the backtest results:

# %%
f.export_backtest_values('stacking').head()
# Out:
#    iter1actuals   iter1preds  iter2actuals   iter2preds  iter3actuals  \
# 0          2256  2196.525109          1851  1748.907666          2459
# 1          2935  2887.275110          2256  2107.096553          1851
# 2          2950  2886.338272          2935  2778.249035          2256
# 3          2982  2847.215433          2950  2824.245425          2935
# 4          2668  2842.609163          2982  2792.369730          2950
#
#     iter3preds  iter4actuals   iter4preds  iter5actuals   iter5preds  \
# 0  2617.085055          3132  2891.188724          2898  3000.707819
# 1  1730.342184          2459  2526.892609          3132  2912.651970
# 2  2133.857057          1851  1772.810500          2459  2470.166493
# 3  2817.896142          2256  2129.491917          1851  1759.261776
# 4  2850.273327          2935  2825.451222          2256  2124.885658
#
#    iter6actuals   iter6preds  iter7actuals   iter7preds  iter8actuals  \
# 0          2964  2898.757554          2794  3042.358565          2282
# 1          2898  2944.232472          2964  2990.421243          2794
# 2          3132  2884.571596          2898  3000.087605          2964
# 3          2459  2470.707758          3132  2900.228563          2898
# 4          1851  1793.430979          2459  2436.946618          3132
#
#     iter8preds  iter9actuals   iter9preds  iter10actuals  iter10preds
# 0  2443.431251          1942  2004.356422           2757  2573.357823
# 1  3132.980634          2282  2482.493067           1942  1935.430388
# 2  3101.904761          2794  3113.348275           2282  2397.588206
# 3  3048.764794          2964  3056.303654           2794  3035.804594
# 4  2949.316929          2898  3041.145918           2964  3029.902606

# %% [markdown]
# ## Plot Forecast

# %%
f.plot('stacking',ci=True)
plt.title('stacking model forecasts',size=16)
plt.show()

# %% [markdown]
# ## View Feature Importance
# - uses [eli5](https://eli5.readthedocs.io/en/latest/overview.html) to extract permutation feature importance on each model input

# %%
f.save_feature_importance()

# %%
f.export_feature_importance('stacking')
# Out:
#                          weight          std
# feature
# AR2                52982.231532  2183.400912
# AR3                 8030.183790   272.640760
# AR4                  601.547348    15.910421
# dayofweek_1           18.377966     0.809954
# dayofweek_2            9.518681     0.724960
# weeksin                8.041128     0.568786
# dayofweek_3            5.251455     0.608201
# dayofyearsin           4.712926     1.026475
# week_28                0.616849     0.040606
# weekcos                0.471701     0.575185
# week_36                0.400132     0.121819
# week_31                0.344054     0.093256
# week_37                0.308649     0.050408
# week_29                0.299373     0.024254
# week_30                0.287075     0.058706
# week_50                0.247487     0.048541
# week_21                0.239003     0.085371
# week_35                0.215014     0.050077
# week_4                 0.212044     0.049969
# week_20                0.195223     0.073234
# week_38                0.182672     0.174803
# week_32                0.169583     0.014614
# week_34                0.165204     0.020275
# week_33                0.156092     0.016871
# week_2                 0.077035     0.014909
# week_12                0.071042     0.019732
# week_18                0.067605     0.002642
# week_51                0.050536     0.199821
# week_39                0.050458     0.158806
# week_11                0.040738     0.004660
# week_3                 0.022195     0.010948
# week_19               -0.002644     0.009874
# week_22               -0.009405     0.060977
# week_45               -0.012962     0.016743
# week_10               -0.015673     0.003808
# week_5                -0.016839     0.056543
# week_23               -0.019518     0.055480
# week_7                -0.020614     0.008664
# week_27               -0.027313     0.008002
# week_6                -0.040387     0.026638
# week_24               -0.047836     0.038011
# week_8                -0.065752     0.048701
# week_13               -0.076391     0.019159
# week_40               -0.096860     0.056770
# week_47               -0.123781     0.027500
# week_9                -0.150939     0.060284
# week_14               -0.173110     0.068833
# week_41               -0.182784     0.068216
# week_25               -0.191604     0.056147
# week_44               -0.200943     0.066049
# week_53               -0.227352     0.030336
# week_42               -0.230821     0.083935
# week_43               -0.238727     0.046312
# week_15               -0.249133     0.072418
# week_46               -0.343373     0.064130
# year                  -0.351067     0.164770
# week_26               -0.366016     0.063536
# week_48               -0.533724     0.128410
# week_16               -0.790971     0.081498
# week_17               -1.015265     0.065669
# monthcos              -1.289013     0.469732
# week_49               -1.513483     0.115074
# is_leap_year_True     -1.585790     0.164608
# week_52               -2.525192     0.260019
# dayofweek_4           -3.490729     1.899989
# quartercos            -4.111148     0.818779
# quartersin            -5.035721     0.543064
# dayofweek_6          -10.966120     0.936105
# monthsin             -13.639820     0.427061
# dayofweek_5          -30.108198     1.990415
# dayofyearcos         -32.156775     1.737901
# AR21                -515.254487    11.020202
# AR5                -3511.619001   116.788278
# AR14               -3927.898101   104.971985
# AR28              -30866.348550  1602.948818
# AR6               -58412.932157  2413.383235
# AR1               -75404.761159  3032.381265
# AR7               -96191.155375  1085.723595

# %% [markdown]
# Many of the model inputs seemed to have actually hurt the model's performance. However, this doesn't mean we should remove each of these features, as each one is tested one at a time, independent of all others. Therefore, removing all negatively performing features could harm the model. We could try removing features one at a time, but without a sound theoretical justification to do so, we might overfit our models. The feature importance can, however, serve to give us insight to which features make our model perform well and help us think more deeply about how to extract accurate forecasts.
