# %% [markdown]
# # Scikit-Learn Models
# This notebook showcases the scalecast wrapper around scikit-learn models.
#
# The data is available for download here: https://www.kaggle.com/datasets/bobnau/daily-website-visitors
# See the blog post: https://medium.com/towards-data-science/expand-your-time-series-arsenal-with-these-models-10c807d37558

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil.relativedelta import relativedelta
from scalecast.Forecaster import Forecaster
from scalecast import GridGenerator
from scalecast.auxmodels import mlp_stack
from tqdm.notebook import tqdm
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.neural_network import MLPRegressor

pd.set_option('max_colwidth',500)
pd.set_option('display.max_rows',500)

# %%
def plot_test_export_summaries(f):
    """ exports the relevant statisitcal information and displays a plot of the test-set results for the last model run
    """
    f.plot_test_set(models=f.estimator,ci=True)
    plt.title(f'{f.estimator} test-set results',size=16)
    plt.show()
    return f.export('model_summaries',determine_best_by='TestSetMAPE')[
        [
            'ModelNickname',
            'HyperParams',
            'TestSetMAPE',
            'TestSetR2',
            'InSampleMAPE',
            'InSampleR2'
        ]
    ]

# %% [markdown]
# We will bring in the default grids from scalecast and tune some of our models this way. For others, we will create our own grids.

# %%
GridGenerator.get_example_grids()

# %%
data = pd.read_csv('daily-website-visitors.csv')
data.head()
# Out:
#    Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0    1     Sunday            1  9/14/2014      2,146         1,582
# 1    2     Monday            2  9/15/2014      3,621         2,528
# 2    3    Tuesday            3  9/16/2014      3,698         2,630
# 3    4  Wednesday            4  9/17/2014      3,667         2,614
# 4    5   Thursday            5  9/18/2014      3,316         2,366
#
#    First.Time.Visits Returning.Visits
# 0               1430              152
# 1               2297              231
# 2               2352              278
# 3               2327              287
# 4               2130              236

# %%
data.shape
# Out:
# (2167, 8)

# %%
f=Forecaster(y=data['First.Time.Visits'],current_dates=data['Date'])
f.plot()
plt.title('Orig Series',size=16)
plt.show()

# %% [markdown]
# Not all models we will showcase come standard in scalecast, but we can easily add them by using the code below:

# %%
f.add_sklearn_estimator(BaggingRegressor,'bagging')
f.add_sklearn_estimator(StackingRegressor,'stacking')

# %% [markdown]
# For more EDA on this dataset, see the prophet example: https://scalecast-examples.readthedocs.io/en/latest/prophet/prophet.html#EDA

# %% [markdown]
# ## Prepare Forecast
# - 60-day forecast horizon
# - 20% test split
# - add time series regressors:
# - 7 autoregressive terms
#   - 4 seasonal autoregressive terms spaced 7-periods apart
#   - month, quarter, week, and day of year with a fournier transformation
#   - dayofweek, leap year, and week as dummy variables
#   - year

# %%
fcst_length = 60
f.generate_future_dates(fcst_length)
f.set_test_length(.2)
f.add_ar_terms(7)
f.add_AR_terms((4,7))
f.add_seasonal_regressors('month','quarter','week','dayofyear',raw=False,sincos=True)
f.add_seasonal_regressors('dayofweek','is_leap_year','week',raw=False,dummy=True,drop_first=True)
f.add_seasonal_regressors('year')
f
# Out:
# Forecaster(
#     DateStartActuals=2014-09-14T00:00:00.000000000
#     DateEndActuals=2020-08-19T00:00:00.000000000
#     Freq=D
#     N_actuals=2167
#     ForecastLength=60
#     Xvars=['AR1', 'AR2', 'AR3', 'AR4', 'AR5', 'AR6', 'AR7', 'AR14', 'AR21', 'AR28', 'monthsin', 'monthcos', 'quartersin', 'quartercos', 'weeksin', 'weekcos', 'dayofyearsin', 'dayofyearcos', 'dayofweek_1', 'dayofweek_2', 'dayofweek_3', 'dayofweek_4', 'dayofweek_5', 'dayofweek_6', 'is_leap_year_True', 'week_10', 'week_11', 'week_12', 'week_13', 'week_14', 'week_15', 'week_16', 'week_17', 'week_18', 'week_19', 'week_2', 'week_20', 'week_21', 'week_22', 'week_23', 'week_24', 'week_25', 'week_26', 'week_27', 'week_28', 'week_29', 'week_3', 'week_30', 'week_31', 'week_32', 'week_33', 'week_34', 'week_35', 'week_36', 'week_37', 'week_38', 'week_39', 'week_4', 'week_40', 'week_41', 'week_42', 'week_43', 'week_44', 'week_45', 'week_46', 'week_47', 'week_48', 'week_49', 'week_5', 'week_50', 'week_51', 'week_52', 'week_53', 'week_6', 'week_7', 'week_8', 'week_9', 'year']
#     Differenced=0
#     TestLength=433
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
#     GridsFile=Grids
# )

# %% [markdown]
# ## MLR
# - use default parameters (which means all input vars are scaled with a minmax scaler by default for all sklearn models)

# %%
f.set_estimator('mlr')
f.manual_forecast(dynamic_testing=fcst_length)

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname HyperParams  TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0           mlr          {}     0.127293   0.770837      0.064186    0.953483

# %% [markdown]
# ## Lasso
# - tune alpha with 100 choices using 3-fold cross validation
# - use 60-step forecast evaluation in each tuning and testing iteration

# %%
f.set_estimator('lasso')
lasso_grid = {'alpha':np.linspace(0,2,100)}
f.ingest_grid(lasso_grid)
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname                     HyperParams  TestSetMAPE  TestSetR2  \
# 0           mlr                              {}     0.127598   0.763020
# 1         lasso   {'alpha': 0.8080808080808082}     0.141144   0.706746
# 2         ridge  {'alpha': 0.20202020202020204}     0.213063   0.355430
#
#    InSampleMAPE  InSampleR2
# 0      0.064186    0.953483
# 1      0.066964    0.950091
# 2      0.064259    0.953370

# %% [markdown]
# ## Ridge
# - tune alpha with the same grid used for lasso

# %%
f.set_estimator('ridge')
f.ingest_grid(lasso_grid)
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname                    HyperParams  TestSetMAPE  TestSetR2  \
# 0           mlr                             {}     0.127598   0.763020
# 1         ridge  {'alpha': 0.7272727272727273}     0.140264   0.744187
# 2         lasso  {'alpha': 0.8080808080808082}     0.141144   0.706746
#
#    InSampleMAPE  InSampleR2
# 0      0.064186    0.953483
# 1      0.064705    0.952604
# 2      0.066964    0.950091

# %% [markdown]
# ## Elasticnet
#
# - this model mixes L1 and L2 regularization parameters
# - its default grid is pretty good for finding the optimal alpha value and l1 ratio

# %%
f.set_estimator('elasticnet')
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname                    HyperParams  TestSetMAPE  TestSetR2  \
# 0           mlr                             {}     0.127598   0.763020
# 1         ridge  {'alpha': 0.7272727272727273}     0.140264   0.744187
# 2    elasticnet  {'alpha': 0.8, 'l1_ratio': 1}     0.141012   0.707796
# 3         lasso  {'alpha': 0.8080808080808082}     0.141144   0.706746
#
#    InSampleMAPE  InSampleR2
# 0      0.064186    0.953483
# 1      0.064705    0.952604
# 2      0.066941    0.950127
# 3      0.066964    0.950091

# %% [markdown]
# ## RF
# ![Random Forest](rf.png)

# %% [markdown]
# create a grid to tune Random Forest with more options than what is available in the default grids

# %%
f.set_estimator('rf')
rf_grid = {
    'max_depth':[2,3,4,5],
    'n_estimators':[100,200,500],
    'max_features':['auto','sqrt','log2'],
    'max_samples':[.75,.9,1],
}
f.ingest_grid(rf_grid)
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0           mlr
# 1         ridge
# 2    elasticnet
# 3         lasso
# 4            rf
#
#                                                                           HyperParams  \
# 0                                                                                  {}
# 1                                                       {'alpha': 0.7272727272727273}
# 2                                                       {'alpha': 0.8, 'l1_ratio': 1}
# 3                                                       {'alpha': 0.8080808080808082}
# 4  {'max_depth': 5, 'n_estimators': 100, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.127598   0.763020      0.064186    0.953483
# 1     0.140264   0.744187      0.064705    0.952604
# 2     0.141012   0.707796      0.066941    0.950127
# 3     0.141144   0.706746      0.066964    0.950091
# 4     0.315796  -0.889240      0.082788    0.918807

# %% [markdown]
# So far, both using a visual inspection and examing its test-set performance, Random Forest does worse than all others.

# %% [markdown]
# ## XGBoost
# - Build a grid to tune XGBoost

# %%
f.set_estimator('xgboost')
xgboost_grid = {
     'n_estimators':[150,200,250],
     'scale_pos_weight':[5,10],
     'learning_rate':[0.1,0.2],
     'gamma':[0,3,5], 
     'subsample':[0.8,0.9]
}
f.ingest_grid(xgboost_grid)
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           mlr
# 2         ridge
# 3    elasticnet
# 4         lasso
# 5            rf
#
#                                                                                         HyperParams  \
# 0  {'n_estimators': 200, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.8}
# 1                                                                                                {}
# 2                                                                     {'alpha': 0.7272727272727273}
# 3                                                                     {'alpha': 0.8, 'l1_ratio': 1}
# 4                                                                     {'alpha': 0.8080808080808082}
# 5                {'max_depth': 5, 'n_estimators': 100, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.110851   0.776521      0.015090    0.997303
# 1     0.127598   0.763020      0.064186    0.953483
# 2     0.140264   0.744187      0.064705    0.952604
# 3     0.141012   0.707796      0.066941    0.950127
# 4     0.141144   0.706746      0.066964    0.950091
# 5     0.315796  -0.889240      0.082788    0.918807

# %% [markdown]
# This is our best model so far using the test MAPE as the metric to determine that by. It appears to be also be highly overfit.

# %% [markdown]
# ## LightGBM
# - Build a grid to tune LightGBM

# %%
f.set_estimator('lightgbm')
lightgbm_grid = {
    'n_estimators':[150,200,250],
    'boosting_type':['gbdt','dart','goss'],
    'max_depth':[1,2,3],
    'learning_rate':[0.001,0.01,0.1],
    'reg_alpha':np.linspace(0,1,5),
    'reg_lambda':np.linspace(0,1,5),
    'num_leaves':np.arange(5,50,5),
}
f.ingest_grid(lightgbm_grid)
f.limit_grid_size(100,random_seed=2)
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           mlr
# 2         ridge
# 3    elasticnet
# 4         lasso
# 5      lightgbm
# 6            rf
#
#                                                                                                                                     HyperParams  \
# 0                                              {'n_estimators': 200, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.8}
# 1                                                                                                                                            {}
# 2                                                                                                                 {'alpha': 0.7272727272727273}
# 3                                                                                                                 {'alpha': 0.8, 'l1_ratio': 1}
# 4                                                                                                                 {'alpha': 0.8080808080808082}
# 5  {'n_estimators': 250, 'boosting_type': 'gbdt', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.5, 'reg_lambda': 0.25, 'num_leaves': 40}
# 6                                                            {'max_depth': 5, 'n_estimators': 100, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.110851   0.776521      0.015090    0.997303
# 1     0.127598   0.763020      0.064186    0.953483
# 2     0.140264   0.744187      0.064705    0.952604
# 3     0.141012   0.707796      0.066941    0.950127
# 4     0.141144   0.706746      0.066964    0.950091
# 5     0.147390   0.694193      0.044831    0.974909
# 6     0.315796  -0.889240      0.082788    0.918807

# %% [markdown]
# ## SGD
# - Use the default Stochastic Gradient Descent grid

# %%
f.set_estimator('sgd')
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           mlr
# 2         ridge
# 3    elasticnet
# 4         lasso
# 5           sgd
# 6      lightgbm
# 7            rf
#
#                                                                                                                                     HyperParams  \
# 0                                              {'n_estimators': 200, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.8}
# 1                                                                                                                                            {}
# 2                                                                                                                 {'alpha': 0.7272727272727273}
# 3                                                                                                                 {'alpha': 0.8, 'l1_ratio': 1}
# 4                                                                                                                 {'alpha': 0.8080808080808082}
# 5                                                                              {'penalty': 'l2', 'l1_ratio': 0.15, 'learning_rate': 'adaptive'}
# 6  {'n_estimators': 250, 'boosting_type': 'gbdt', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.5, 'reg_lambda': 0.25, 'num_leaves': 40}
# 7                                                            {'max_depth': 5, 'n_estimators': 100, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.110851   0.776521      0.015090    0.997303
# 1     0.127598   0.763020      0.064186    0.953483
# 2     0.140264   0.744187      0.064705    0.952604
# 3     0.141012   0.707796      0.066941    0.950127
# 4     0.141144   0.706746      0.066964    0.950091
# 5     0.144113   0.735039      0.065065    0.952108
# 6     0.147390   0.694193      0.044831    0.974909
# 7     0.315796  -0.889240      0.082788    0.918807

# %% [markdown]
# ## KNN
# - Use the default K-nearest Neighbors grid

# %%
f.set_estimator('knn')
f.cross_validate(k=3)
f.auto_forecast()

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           knn
# 2           mlr
# 3         ridge
# 4    elasticnet
# 5         lasso
# 6           sgd
# 7      lightgbm
# 8            rf
#
#                                                                                                                                     HyperParams  \
# 0                                              {'n_estimators': 200, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.8}
# 1                                                                                                     {'n_neighbors': 9, 'weights': 'distance'}
# 2                                                                                                                                            {}
# 3                                                                                                                 {'alpha': 0.7272727272727273}
# 4                                                                                                                 {'alpha': 0.8, 'l1_ratio': 1}
# 5                                                                                                                 {'alpha': 0.8080808080808082}
# 6                                                                              {'penalty': 'l2', 'l1_ratio': 0.15, 'learning_rate': 'adaptive'}
# 7  {'n_estimators': 250, 'boosting_type': 'gbdt', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.5, 'reg_lambda': 0.25, 'num_leaves': 40}
# 8                                                            {'max_depth': 5, 'n_estimators': 100, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.110851   0.776521      0.015090    0.997303
# 1     0.111574   0.786372      0.000000    1.000000
# 2     0.127598   0.763020      0.064186    0.953483
# 3     0.140264   0.744187      0.064705    0.952604
# 4     0.141012   0.707796      0.066941    0.950127
# 5     0.141144   0.706746      0.066964    0.950091
# 6     0.144113   0.735039      0.065065    0.952108
# 7     0.147390   0.694193      0.044831    0.974909
# 8     0.315796  -0.889240      0.082788    0.918807

# %% [markdown]
# KNN is our most overfit model so far, but it fits the test-set pretty well.

# %% [markdown]
# ## BaggingRegressor
# - Like Random Forest is a bagging ensemble model using decision trees, we can use a bagging estimator that uses a three-layered mulit-level perceptron to see if the added complexity improves where the Random Forest couldn't

# %%
f.set_estimator('bagging')
f.manual_forecast(
    base_estimator = MLPRegressor(
        hidden_layer_sizes=(100,100,100)
        ,solver='lbfgs'
    ),
    max_samples = 0.9,
    max_features = 0.5,
)

# %%
plot_test_export_summaries(f)
# Out:
#   ModelNickname  \
# 0       xgboost
# 1           knn
# 2       bagging
# 3           mlr
# 4         ridge
# 5    elasticnet
# 6         lasso
# 7           sgd
# 8      lightgbm
# 9            rf
#
#                                                                                                                                     HyperParams  \
# 0                                              {'n_estimators': 200, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.8}
# 1                                                                                                     {'n_neighbors': 9, 'weights': 'distance'}
# 2                 {'base_estimator': MLPRegressor(hidden_layer_sizes=(100, 100, 100), solver='lbfgs'), 'max_samples': 0.9, 'max_features': 0.5}
# 3                                                                                                                                            {}
# 4                                                                                                                 {'alpha': 0.7272727272727273}
# 5                                                                                                                 {'alpha': 0.8, 'l1_ratio': 1}
# 6                                                                                                                 {'alpha': 0.8080808080808082}
# 7                                                                              {'penalty': 'l2', 'l1_ratio': 0.15, 'learning_rate': 'adaptive'}
# 8  {'n_estimators': 250, 'boosting_type': 'gbdt', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.5, 'reg_lambda': 0.25, 'num_leaves': 40}
# 9                                                            {'max_depth': 5, 'n_estimators': 100, 'max_features': 'auto', 'max_samples': 0.75}
#
#    TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0     0.110851   0.776521      0.015090    0.997303
# 1     0.111574   0.786372      0.000000    1.000000
# 2     0.127267   0.738404      0.059288    0.958289
# 3     0.127598   0.763020      0.064186    0.953483
# 4     0.140264   0.744187      0.064705    0.952604
# 5     0.141012   0.707796      0.066941    0.950127
# 6     0.141144   0.706746      0.066964    0.950091
# 7     0.144113   0.735039      0.065065    0.952108
# 8     0.147390   0.694193      0.044831    0.974909
# 9     0.315796  -0.889240      0.082788    0.918807

# %% [markdown]
# This is the best-performing model yet, with less overfitting than XGBoost and KNN.

# %% [markdown]
# ## StackingRegressor
# This model will use the predictions of other models as inputs to a "final estimator". It's added complexity can mean better performance, although not always.
#
# ![Stacking Regressor](stacking.png)
#
# The model that we employ uses the bagged MLP regressor from the previous section as its final estimator, and the tuned knn, xgboost, lightgbm, and sgd models as its inputs.
#
# ![MLP Stack](mlp_stack.png)

# %%
f.plot_fitted()
plt.title('all models fitted vals',size=16)
plt.show()

# %% [markdown]
# Sometimes seeing the fitted values can give a good idea of which models to stack, as you want models that can predict both the highs and lows of the series. However, this graph didn't tell us much.
#
# We use four of our best performing models to create the model inputs. We use a bagging estimator as the final model.

# %%
f.set_estimator('stacking')
results = f.export('model_summaries')
estimators = [
    'knn',
    'xgboost',
    'lightgbm',
    'sgd',
]

mlp_stack(f,estimators,call_me='stacking')

# %%
plot_test_export_summaries(f)
# Out:
#    ModelNickname  \
# 0       stacking
# 1        xgboost
# 2            knn
# 3        bagging
# 4            mlr
# 5          ridge
# 6     elasticnet
# 7          lasso
# 8            sgd
# 9       lightgbm
# 10            rf
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             HyperParams  \
# 0   {'estimators': [('knn', KNeighborsRegressor(n_neighbors=9, weights='distance')), ('xgboost', XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=0, gpu_id=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#            ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                      {'n_estimators': 200, 'scale_pos_weight': 5, 'learning_rate': 0.1, 'gamma': 0, 'subsample': 0.8}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'n_neighbors': 9, 'weights': 'distance'}
# 3                                                                                                                                                                                                                                                                                                                                                                                         {'base_estimator': MLPRegressor(hidden_layer_sizes=(100, 100, 100), solver='lbfgs'), 'max_samples': 0.9, 'max_features': 0.5}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {}
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {'alpha': 0.7272727272727273}
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {'alpha': 0.8, 'l1_ratio': 1}
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {'alpha': 0.8080808080808082}
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'penalty': 'l2', 'l1_ratio': 0.15, 'learning_rate': 'adaptive'}
# 9                                                                                                                                                                                                                                                                                                                                                                          {'n_estimators': 250, 'boosting_type': 'gbdt', 'max_depth': 3, 'learning_rate': 0.1, 'reg_alpha': 0.5, 'reg_lambda': 0.25, 'num_leaves': 40}
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                   {'max_depth': 5, 'n_estimators': 100, 'max_features': 'auto', 'max_samples': 0.75}
#
#     TestSetMAPE  TestSetR2  InSampleMAPE  InSampleR2
# 0      0.103819   0.843684      0.033040    0.986936
# 1      0.110851   0.776521      0.015090    0.997303
# 2      0.111574   0.786372      0.000000    1.000000
# 3      0.127267   0.738404      0.059288    0.958289
# 4      0.127598   0.763020      0.064186    0.953483
# 5      0.140264   0.744187      0.064705    0.952604
# 6      0.141012   0.707796      0.066941    0.950127
# 7      0.141144   0.706746      0.066964    0.950091
# 8      0.144113   0.735039      0.065065    0.952108
# 9      0.147390   0.694193      0.044831    0.974909
# 10     0.315796  -0.889240      0.082788    0.918807

# %% [markdown]
# This is our best model with lower amounts of overfitting than some of our other models. We will choose it to make our final forecasts with.

# %% [markdown]
# ## Backtesting
# - Backtesting is an extra step to validate our model's performance. It evaluates the average error over the last n amount of forecast horizons had that particular model been selected to forecast with. Read more about it in the scalecast documentation: https://scalecast.readthedocs.io/en/latest/Forecaster/Forecaster.html#src.scalecast.Forecaster.Forecaster.backtest

# %%
f.backtest('stacking')

# %% [markdown]
# View the backtest metrics:

# %%
f.export_backtest_metrics('stacking')
# Out:
#            iter1       iter2       iter3       iter4       iter5      iter6  \
# RMSE  266.400003  196.403536  204.046107  169.326852  176.096851  154.22867
# MAE   185.400699  154.755792  164.580556  136.124901   141.01542  122.80009
# R2      0.592496    0.762763    0.745587    0.838546    0.827614   0.864172
# MAPE    0.090493    0.069883     0.07455    0.061683    0.062766   0.053993
#
#            iter7       iter8       iter9      iter10        mean
# RMSE  185.728452  188.194788  176.558055  174.198804  189.118212
# MAE   148.915805  152.884655  138.610745  142.297254  148.738592
# R2      0.805577    0.800355    0.825535    0.833678    0.789632
# MAPE    0.066081    0.067897    0.061205    0.064138    0.067269

# %% [markdown]
# And the backtest results:

# %%
f.export_backtest_values('stacking').head()
# Out:
#    iter1actuals   iter1preds  iter2actuals   iter2preds  iter3actuals  \
# 0          2256  2176.509306          1851  1777.090716          2459
# 1          2935  2877.848546          2256  2121.936791          1851
# 2          2950  2866.779803          2935  2843.613194          2256
# 3          2982  2864.013515          2950  2879.272007          2935
# 4          2668  2883.414616          2982  2865.107603          2950
#
#     iter3preds  iter4actuals   iter4preds  iter5actuals   iter5preds  \
# 0  2613.926115          3132  2857.570217          2898  2984.073348
# 1  1847.179499          2459  2507.561088          3132  2914.910790
# 2  2167.687999          1851  1812.687699          2459  2482.731978
# 3  2864.823303          2256  2123.321662          1851  1793.001270
# 4  2896.882935          2935  2823.937531          2256  2135.064635
#
#    iter6actuals   iter6preds  iter7actuals   iter7preds  iter8actuals  \
# 0          2964  2902.954618          2794  3017.045737          2282
# 1          2898  2971.582805          2964  3047.630655          2794
# 2          3132  2921.999770          2898  3027.536129          2964
# 3          2459  2544.114180          3132  2916.441337          2898
# 4          1851  1853.509328          2459  2484.214742          3132
#
#     iter8preds  iter9actuals   iter9preds  iter10actuals  iter10preds
# 0  2397.092100          1942  2000.563352           2757  2525.245096
# 1  3058.969577          2282  2417.550129           1942  1907.265200
# 2  3012.163462          2794  3022.019759           2282  2408.428745
# 3  2991.002648          2964  3023.507339           2794  3076.160418
# 4  2923.599770          2898  3006.495626           2964  3046.378286

# %% [markdown]
# ## Plot Forecast

# %%
f.plot('stacking',ci=True)
plt.title('stacking model forecasts',size=16)
plt.show()

# %% [markdown]
# ## View Feature Importance
# - uses [eli5](https://eli5.readthedocs.io/en/latest/overview.html) to extract permutation feature importance on each model input

# %%
f.save_feature_importance()

# %%
f.export_feature_importance('stacking')
# Out:
#                      weight       std
# feature
# AR7                0.208260  0.008786
# AR1                0.046188  0.012140
# AR28               0.042537  0.002566
# dayofweek_5        0.035892  0.006153
# AR2                0.032168  0.000413
# dayofweek_4        0.015810  0.000991
# dayofweek_1        0.009593  0.002125
# dayofweek_2        0.006616  0.002028
# quartercos         0.005339  0.000670
# dayofweek_3        0.005261  0.001420
# week_2             0.003419  0.000710
# week_28            0.001920  0.000184
# dayofweek_6        0.001624  0.001644
# monthsin           0.001257  0.000772
# week_29            0.000412  0.000135
# week_13            0.000212  0.000048
# week_30            0.000141  0.000294
# week_18            0.000140  0.000094
# week_47            0.000130  0.000296
# is_leap_year_True  0.000083  0.000165
# week_50            0.000044  0.000146
# week_32            0.000028  0.000124
# week_14            0.000002  0.000164
# week_27           -0.000009  0.000080
# quartersin        -0.000056  0.000603
# week_10           -0.000061  0.000075
# week_11           -0.000077  0.000087
# week_45           -0.000090  0.000102
# week_46           -0.000093  0.000284
# week_19           -0.000099  0.000154
# week_35           -0.000115  0.000107
# week_31           -0.000119  0.000082
# week_33           -0.000130  0.000069
# week_7            -0.000214  0.000040
# week_34           -0.000242  0.000224
# week_3            -0.000280  0.000028
# week_43           -0.000331  0.000081
# week_8            -0.000364  0.000068
# week_12           -0.000386  0.000241
# week_15           -0.000405  0.000116
# week_36           -0.000413  0.000190
# week_44           -0.000468  0.000157
# week_9            -0.000469  0.000122
# AR21              -0.000511  0.000441
# week_20           -0.000737  0.000158
# week_24           -0.000791  0.000095
# week_53           -0.000877  0.000153
# week_37           -0.000955  0.000196
# week_23           -0.000989  0.000179
# week_26           -0.001070  0.000157
# week_25           -0.001090  0.000257
# week_6            -0.001193  0.000229
# week_48           -0.001285  0.000158
# week_38           -0.001415  0.000167
# week_42           -0.001419  0.000071
# week_40           -0.001460  0.000300
# week_21           -0.001671  0.000254
# week_5            -0.001822  0.000235
# week_17           -0.002034  0.000473
# week_22           -0.002039  0.000121
# week_39           -0.002065  0.000138
# week_41           -0.002089  0.000294
# AR4               -0.002436  0.000467
# year              -0.002646  0.000372
# week_16           -0.002812  0.000235
# week_49           -0.003544  0.000344
# AR14              -0.003830  0.001049
# week_4            -0.004176  0.000244
# week_51           -0.005853  0.001910
# weeksin           -0.006055  0.000413
# week_52           -0.008874  0.000873
# weekcos           -0.009251  0.000531
# AR3               -0.010029  0.000921
# AR5               -0.010798  0.000814
# dayofyearsin      -0.016606  0.001131
# AR6               -0.021777  0.002070
# monthcos          -0.023315  0.000761
# dayofyearcos      -0.074700  0.004789

# %% [markdown]
# Many of the model inputs seemed to have actually hurt the model's performance. However, this doesn't mean we should remove each of these features, as each one is tested one at a time, independent of all others. Therefore, removing all negatively performing features could harm the model. We could try removing features one at a time, but without a sound theoretical justification to do so, we might overfit our models. The feature importance can, however, serve to give us insight to which features make our model perform well and help us think more deeply about how to extract accurate forecasts.
